# %%
import os
import cv2
import collections
import time 
import tqdm
from PIL import Image
from functools import partial
train_on_gpu = True
#import apex

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

import torchvision
import torchvision.transforms as transforms
import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data.sampler import SubsetRandomSampler
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR

import albumentations as albu
from albumentations import pytorch as AT

from catalyst.data import Augmentor
from catalyst.dl import utils
from catalyst.data.reader import ImageReader, ScalarReader, ReaderCompose, LambdaReader
from catalyst.dl.runner import SupervisedRunner
from catalyst.contrib.models.segmentation import Unet
from catalyst.dl.callbacks import DiceCallback, EarlyStoppingCallback, InferCallback, CheckpointCallback
from apex import amp
import segmentation_models_pytorch as smp

# %%
def get_img(x, folder: str='train_img'):
    """
    Return image based on image name and folder.
    """
    data_folder = f"{path}/{folder}"
    image_path = os.path.join(data_folder, x)
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img


def rle_decode(mask_rle: str = '', shape: tuple = (1400, 2100)):
    '''
    Decode rle encoded mask.
    
    :param mask_rle: run-length as string formatted (start length)
    :param shape: (height, width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0] * shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape, order='F')


def make_mask(df: pd.DataFrame, image_name: str='img.jpg', shape: tuple = (1400, 2100)):
    """
    Create mask based on df, image name and shape.
    """
    encoded_masks = df.loc[df['im_id'] == image_name, 'EncodedPixels']
    masks = np.zeros((shape[0], shape[1], 4), dtype=np.float32)

    for idx, label in enumerate(encoded_masks.values):
        if label is not np.nan:
            mask = rle_decode(label)
            masks[:, :, idx] = mask
            
    return masks


def to_tensor(x, **kwargs):
    """
    Convert image or mask.
    """
    return x.transpose(2, 0, 1).astype('float32')


def mask2rle(img):
    '''
    Convert mask to rle.
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)


def visualize(image, mask, original_image=None, original_mask=None):
    """
    Plot image and masks.
    If two pairs of images and masks are passes, show both.
    """
    fontsize = 14
    class_dict = {0: 'Fish', 1: 'Flower', 2: 'Gravel', 3: 'Sugar'}
    
    if original_image is None and original_mask is None:
        f, ax = plt.subplots(1, 5, figsize=(24, 24))

        ax[0].imshow(image)
        for i in range(4):
            ax[i + 1].imshow(mask[:, :, i])
            ax[i + 1].set_title(f'Mask {class_dict[i]}', fontsize=fontsize)
    else:
        f, ax = plt.subplots(2, 5, figsize=(24, 12))

        ax[0, 0].imshow(original_image)
        ax[0, 0].set_title('Original image', fontsize=fontsize)
                
        for i in range(4):
            ax[0, i + 1].imshow(original_mask[:, :, i])
            ax[0, i + 1].set_title(f'Original mask {class_dict[i]}', fontsize=fontsize)
        
        ax[1, 0].imshow(image)
        ax[1, 0].set_title('Transformed image', fontsize=fontsize)
        
        
        for i in range(4):
            ax[1, i + 1].imshow(mask[:, :, i])
            ax[1, i + 1].set_title(f'Transformed mask {class_dict[i]}', fontsize=fontsize)
            
            
def visualize_with_raw(image, mask, original_image=None, original_mask=None, raw_image=None, raw_mask=None):
    """
    Plot image and masks.
    If two pairs of images and masks are passes, show both.
    """
    fontsize = 14
    class_dict = {0: 'Fish', 1: 'Flower', 2: 'Gravel', 3: 'Sugar'}

    f, ax = plt.subplots(3, 5, figsize=(24, 12))

    ax[0, 0].imshow(original_image)
    ax[0, 0].set_title('Original image', fontsize=fontsize)

    for i in range(4):
        ax[0, i + 1].imshow(original_mask[:, :, i])
        ax[0, i + 1].set_title(f'Original mask {class_dict[i]}', fontsize=fontsize)


    ax[1, 0].imshow(raw_image)
    ax[1, 0].set_title('Original image', fontsize=fontsize)

    for i in range(4):
        ax[1, i + 1].imshow(raw_mask[:, :, i])
        ax[1, i + 1].set_title(f'Raw predicted mask {class_dict[i]}', fontsize=fontsize)
        
    ax[2, 0].imshow(image)
    ax[2, 0].set_title('Transformed image', fontsize=fontsize)


    for i in range(4):
        ax[2, i + 1].imshow(mask[:, :, i])
        ax[2, i + 1].set_title(f'Predicted mask with processing {class_dict[i]}', fontsize=fontsize)
            
            
def plot_with_augmentation(image, mask, augment):
    """
    Wrapper for `visualize` function.
    """
    augmented = augment(image=image, mask=mask)
    image_flipped = augmented['image']
    mask_flipped = augmented['mask']
    visualize(image_flipped, mask_flipped, original_image=image, original_mask=mask)
    
    
sigmoid = lambda x: 1 / (1 + np.exp(-x))


def post_process(probability, threshold, min_size):
    """
    Post processing of each predicted mask, components with lesser number of pixels
    than `min_size` are ignored
    """
    # don't remember where I saw it
    mask = cv2.threshold(probability, threshold, 1, cv2.THRESH_BINARY)[1]
    num_component, component = cv2.connectedComponents(mask.astype(np.uint8))
    predictions = np.zeros((350, 525), np.float32)
    num = 0
    for c in range(1, num_component):
        p = (component == c)
        if p.sum() > min_size:
            predictions[p] = 1
            num += 1
    return predictions, num


def get_training_augmentation():
    train_transform = [

        albu.HorizontalFlip(p=0.5),
        albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=0.5, border_mode=0),
        albu.GridDistortion(p=0.5),
        albu.OpticalDistortion(p=0.5, distort_limit=2, shift_limit=0.5),
        albu.Resize(320, 640)
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        albu.Resize(320, 640)
    ]
    return albu.Compose(test_transform)


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)


def dice(img1, img2):
    img1 = np.asarray(img1).astype(np.bool)
    img2 = np.asarray(img2).astype(np.bool)

    intersection = np.logical_and(img1, img2)

    return 2. * intersection.sum() / (img1.sum() + img2.sum())

# %%
path = '../data'
os.listdir(path)
# Out:
# ['test_img', 'train_img', 'train.csv', 'sample_submission.csv']

# %%
train = pd.read_csv(f'{path}/train.csv')
sub = pd.read_csv(f'{path}/sample_submission.csv')

# %%
train.head()
# Out:
#           Image_Label                                      EncodedPixels
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...

# %%
n_train = len(os.listdir(f'{path}/train_img'))
n_test = len(os.listdir(f'{path}/test_img'))
print(f'There are {n_train} images in train dataset')
print(f'There are {n_test} images in test dataset')
# Out:
# There are 5546 images in train dataset
# There are 3698 images in test dataset

# %%
train['Image_Label'].apply(lambda x: x.split('_')[1]).value_counts()
# Out:
# Flower    5546
# Sugar     5546
# Fish      5546
# Gravel    5546
# Name: Image_Label, dtype: int64

# %%
train.loc[train['EncodedPixels'].isnull() == False, 'Image_Label'].apply(lambda x: x.split('_')[1]).value_counts()
# Out:
# Sugar     3751
# Gravel    2939
# Fish      2781
# Flower    2365
# Name: Image_Label, dtype: int64

# %%
train.loc[train['EncodedPixels'].isnull() == False, 'Image_Label'].apply(lambda x: x.split('_')[0]).value_counts().value_counts()
# Out:
# 2    2372
# 3    1560
# 1    1348
# 4     266
# Name: Image_Label, dtype: int64

# %%
train['label'] = train['Image_Label'].apply(lambda x: x.split('_')[1])
train['im_id'] = train['Image_Label'].apply(lambda x: x.split('_')[0])


sub['label'] = sub['Image_Label'].apply(lambda x: x.split('_')[1])
sub['im_id'] = sub['Image_Label'].apply(lambda x: x.split('_')[0])

# %%
train.head(5)
# Out:
#           Image_Label                                      EncodedPixels  \
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...
#
#     label        im_id
# 0    Fish  0011165.jpg
# 1  Flower  0011165.jpg
# 2  Gravel  0011165.jpg
# 3   Sugar  0011165.jpg
# 4    Fish  002be4f.jpg

# %%
fig = plt.figure(figsize=(25, 16))
for j, im_id in enumerate(np.random.choice(train['im_id'].unique(), 4)):
    for i, (idx, row) in enumerate(train.loc[train['im_id'] == im_id].iterrows()):
        ax = fig.add_subplot(5, 4, j * 4 + i + 1, xticks=[], yticks=[])
        im = Image.open(f"{path}/train_img/{row['Image_Label'].split('_')[0]}")
        plt.imshow(im)
        mask_rle = row['EncodedPixels']
        try: # label might not be there!
            mask = rle_decode(mask_rle)
        except:
            mask = np.zeros((1400, 2100))
        plt.imshow(mask, alpha=0.5, cmap='gray')
        ax.set_title(f"Image: {row['Image_Label'].split('_')[0]}. Label: {row['label']}")

# %%
id_mask_count = train.loc[train['EncodedPixels'].isnull() == False, 'Image_Label'].apply(lambda x: x.split('_')[0]).value_counts().\
reset_index().rename(columns={'index': 'img_id', 'Image_Label': 'count'})
train_ids, valid_ids = train_test_split(id_mask_count['img_id'].values, random_state=42, stratify=id_mask_count['count'], test_size=0.1)
test_ids = sub['Image_Label'].apply(lambda x: x.split('_')[0]).drop_duplicates().values

# %%
image_name = '8242ba0.jpg'
image = get_img(image_name)
mask = make_mask(train, image_name)

# %%
visualize(image, mask)

# %%
plot_with_augmentation(image, mask, albu.HorizontalFlip(p=1))

# %%
plot_with_augmentation(image, mask, albu.VerticalFlip(p=1))

# %%
plot_with_augmentation(image, mask, albu.RandomRotate90(p=1))

# %%
plot_with_augmentation(image, mask, albu.ElasticTransform(p=1, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03))

# %%
plot_with_augmentation(image, mask, albu.GridDistortion(p=1))

# %%
plot_with_augmentation(image, mask, albu.OpticalDistortion(p=1, distort_limit=2, shift_limit=0.5))

# %%
class CloudDataset(Dataset):
    def __init__(self, df: pd.DataFrame = None, datatype: str = 'train', img_ids: np.array = None,
                 transforms = albu.Compose([albu.HorizontalFlip(),albu.VerticalFlip(),
                                            albu.CLAHE(),
                                            albu.GaussianBlur(blur_limit=7, always_apply=False, p=0.5),
                                            albu.MedianBlur(blur_limit=7, always_apply=False, p=0.5),
                                            albu.RandomContrast(limit=0.2, always_apply=False, p=0.5),
                                            albu.RandomBrightness(limit=0.2, always_apply=False, p=0.5),
                                            albu.Rotate(limit=180)
                                            
                                            ,AT.ToTensor()]),
                preprocessing=preprocessing_fn):
        self.df = df
        if datatype != 'test':
            self.data_folder = f"{path}/train_img"
        else:
            self.data_folder = f"{path}/test_img"
        self.img_ids = img_ids
        self.transforms = transforms
        self.preprocessing = preprocessing

    def __getitem__(self, idx):
        image_name = self.img_ids[idx]
        mask = make_mask(self.df, image_name)
        image_path = os.path.join(self.data_folder, image_name)
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        augmented = self.transforms(image=img, mask=mask)
        img = augmented['image']
        mask = augmented['mask']
        if self.preprocessing:
            preprocessed = self.preprocessing(image=img, mask=mask)
            img = preprocessed['image']
            mask = preprocessed['mask']
        return img, mask

    def __len__(self):
        return len(self.img_ids)

# %%
ENCODER = 'resnet34'
ENCODER_WEIGHTS = 'imagenet'
DEVICE = 'cuda'

ACTIVATION = None
model = smp.Unet(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    classes=4, 
    activation=ACTIVATION,
)
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
num_workers = 8
bs = 64
train_dataset = CloudDataset(df=train, datatype='train', img_ids=train_ids, transforms = get_training_augmentation(), preprocessing=get_preprocessing(preprocessing_fn))
valid_dataset = CloudDataset(df=train, datatype='valid', img_ids=valid_ids, transforms = get_validation_augmentation(), preprocessing=get_preprocessing(preprocessing_fn))

train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True, num_workers=num_workers)
valid_loader = DataLoader(valid_dataset, batch_size=bs, shuffle=False, num_workers=num_workers)

loaders = {
    "train": train_loader,
    "valid": valid_loader
}

# %%
def dice_loss(input, target):
    input = torch.sigmoid(input)
    smooth = 1.0
    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    return ((2.0 * intersection + smooth) / (iflat.sum() + tflat.sum() + smooth))


class FocalLoss(nn.Module):
    def __init__(self, gamma):
        super().__init__()
        self.gamma = gamma

    def forward(self, input, target):
        if not (target.size() == input.size()):
            raise ValueError("Target size ({}) must be the same as input size ({})"
                             .format(target.size(), input.size()))
        max_val = (-input).clamp(min=0)
        loss = input - input * target + max_val + \
            ((-max_val).exp() + (-input - max_val).exp()).log()
        invprobs = F.logsigmoid(-input * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        return loss.mean()


class MixedLoss(nn.Module):
    def __init__(self, alpha, gamma):
        super().__init__()
        self.alpha = alpha
        self.focal = FocalLoss(gamma)

    def forward(self, input, target):
        loss = self.alpha*self.focal(input, target) - torch.log(dice_loss(input, target))
        return loss.mean()

# %%
import apex
num_epochs = 50
logdir = "./logs/segmentation_unet_resnet34"

# model, criterion, optimizer
optimizer = torch.optim.Adam([
    {'params': model.decoder.parameters(), 'lr': 1e-2}, 
    {'params': model.encoder.parameters(), 'lr': 1e-3},  
])
opt_level = 'O1'
model.cuda()
model, optimizer = amp.initialize(model, optimizer, opt_level=opt_level)
scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=2)
# criterion = MixedLoss(10.0, 2.0)
criterion = smp.utils.losses.BCEDiceLoss(eps=1.)
runner = SupervisedRunner()
# Out:
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic

# %%
# num_epochs = 29
# logdir = "./logs/segmentation"

# # model, criterion, optimizer
# optimizer = torch.optim.Adam([
#     {'params': model.decoder.parameters(), 'lr': 1e-2}, 
#     {'params': model.encoder.parameters(), 'lr': 1e-3},  
# ])
# scheduler = ReduceLROnPlateau(optimizer, factor=0.15, patience=2)
# criterion = smp.utils.losses.BCEDiceLoss(eps=1.)
# runner = SupervisedRunner()

# %%
runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    loaders=loaders,
    callbacks=[DiceCallback(), EarlyStoppingCallback(patience=5, min_delta=0.001)],
    logdir=logdir,
    num_epochs=num_epochs,
    verbose=True
)
# Out:
# 0/50 * Epoch (train):   0% 0/78 [00:00<?, ?it/s]
# 0/50 * Epoch (train):   0% 0/78 [00:23<?, ?it/s, _timers/_fps=2.929, dice=0.237, loss=1.566]
# 0/50 * Epoch (train):   1% 1/78 [00:23<29:54, 23.30s/it, _timers/_fps=2.929, dice=0.237, loss=1.566]
# 0/50 * Epoch (train):   1% 1/78 [00:24<29:54, 23.30s/it, _timers/_fps=273.539, dice=0.213, loss=1.519]
# 0/50 * Epoch (train):   3% 2/78 [00:24<21:18, 16.82s/it, _timers/_fps=273.539, dice=0.213, loss=1.519]
# 0/50 * Epoch (train):   3% 2/78 [00:26<21:18, 16.82s/it, _timers/_fps=176.053, dice=0.234, loss=1.439]
# 0/50 * Epoch (train):   4% 3/78 [00:26<15:23, 12.31s/it, _timers/_fps=176.053, dice=0.234, loss=1.439]
# 0/50 * Epoch (train):   4% 3/78 [00:28<15:23, 12.31s/it, _timers/_fps=282.834, dice=0.238, loss=1.384]
# 0/50 * Epoch (train):   5% 4/78 [00:28<11:15,  9.13s/it, _timers/_fps=282.834, dice=0.238, loss=1.384]
# 0/50 * Epoch (train):   5% 4/78 [00:30<11:15,  9.13s/it, _timers/_fps=185.230, dice=0.227, loss=1.355]
# 0/50 * Epoch (train):   6% 5/78 [00:30<08:25,  6.92s/it, _timers/_fps=185.230, dice=0.227, loss=1.355]
# 0/50 * Epoch (train):   6% 5/78 [00:32<08:25,  6.92s/it, _timers/_fps=214.220, dice=0.243, loss=1.319]
# 0/50 * Epoch (train):   8% 6/78 [00:32<06:27,  5.38s/it, _timers/_fps=214.220, dice=0.243, loss=1.319]
# 0/50 * Epoch (train):   8% 6/78 [00:33<06:27,  5.38s/it, _timers/_fps=212.396, dice=0.274, loss=1.262]
# 0/50 * Epoch (train):   9% 7/78 [00:33<05:04,  4.29s/it, _timers/_fps=212.396, dice=0.274, loss=1.262]
# 0/50 * Epoch (train):   9% 7/78 [00:35<05:04,  4.29s/it, _timers/_fps=270.708, dice=0.263, loss=1.265]
# 0/50 * Epoch (train):  10% 8/78 [00:35<04:05,  3.51s/it, _timers/_fps=270.708, dice=0.263, loss=1.265]
# 0/50 * Epoch (train):  10% 8/78 [00:46<04:05,  3.51s/it, _timers/_fps=6.584, dice=0.257, loss=1.252]
# 0/50 * Epoch (train):  12% 9/78 [00:46<06:40,  5.81s/it, _timers/_fps=6.584, dice=0.257, loss=1.252]
# 0/50 * Epoch (train):  12% 9/78 [00:48<06:40,  5.81s/it, _timers/_fps=291.531, dice=0.267, loss=1.211]
# 0/50 * Epoch (train):  13% 10/78 [00:48<05:10,  4.56s/it, _timers/_fps=291.531, dice=0.267, loss=1.211]
# 0/50 * Epoch (train):  13% 10/78 [00:49<05:10,  4.56s/it, _timers/_fps=301.236, dice=0.283, loss=1.183]
# 0/50 * Epoch (train):  14% 11/78 [00:49<04:07,  3.69s/it, _timers/_fps=301.236, dice=0.283, loss=1.183]
# 0/50 * Epoch (train):  14% 11/78 [00:51<04:07,  3.69s/it, _timers/_fps=289.839, dice=0.267, loss=1.185]
# 0/50 * Epoch (train):  15% 12/78 [00:51<03:23,  3.08s/it, _timers/_fps=289.839, dice=0.267, loss=1.185]
# 0/50 * Epoch (train):  15% 12/78 [00:53<03:23,  3.08s/it, _timers/_fps=230.991, dice=0.269, loss=1.172]
# 0/50 * Epoch (train):  17% 13/78 [00:53<02:54,  2.68s/it, _timers/_fps=230.991, dice=0.269, loss=1.172]
# 0/50 * Epoch (train):  17% 13/78 [00:55<02:54,  2.68s/it, _timers/_fps=258.777, dice=0.285, loss=1.153]
# 0/50 * Epoch (train):  18% 14/78 [00:55<02:32,  2.38s/it, _timers/_fps=258.777, dice=0.285, loss=1.153]
# 0/50 * Epoch (train):  18% 14/78 [00:56<02:32,  2.38s/it, _timers/_fps=197.601, dice=0.289, loss=1.121]
# 0/50 * Epoch (train):  19% 15/78 [00:56<02:18,  2.20s/it, _timers/_fps=197.601, dice=0.289, loss=1.121]
# 0/50 * Epoch (train):  19% 15/78 [00:58<02:18,  2.20s/it, _timers/_fps=289.229, dice=0.302, loss=1.111]
# 0/50 * Epoch (train):  21% 16/78 [00:58<02:06,  2.03s/it, _timers/_fps=289.229, dice=0.302, loss=1.111]
# 0/50 * Epoch (train):  21% 16/78 [01:12<02:06,  2.03s/it, _timers/_fps=5.072, dice=0.310, loss=1.080]
# 0/50 * Epoch (train):  22% 17/78 [01:12<05:44,  5.64s/it, _timers/_fps=5.072, dice=0.310, loss=1.080]
# 0/50 * Epoch (train):  22% 17/78 [01:14<05:44,  5.64s/it, _timers/_fps=166.540, dice=0.291, loss=1.098]
# 0/50 * Epoch (train):  23% 18/78 [01:14<04:29,  4.49s/it, _timers/_fps=166.540, dice=0.291, loss=1.098]
# 0/50 * Epoch (train):  23% 18/78 [01:16<04:29,  4.49s/it, _timers/_fps=164.390, dice=0.298, loss=1.082]
# 0/50 * Epoch (train):  24% 19/78 [01:16<03:36,  3.68s/it, _timers/_fps=164.390, dice=0.298, loss=1.082]
# 0/50 * Epoch (train):  24% 19/78 [01:17<03:36,  3.68s/it, _timers/_fps=172.983, dice=0.312, loss=1.051]
# 0/50 * Epoch (train):  26% 20/78 [01:17<03:01,  3.12s/it, _timers/_fps=172.983, dice=0.312, loss=1.051]
# 0/50 * Epoch (train):  26% 20/78 [01:19<03:01,  3.12s/it, _timers/_fps=179.562, dice=0.306, loss=1.083]
# 0/50 * Epoch (train):  27% 21/78 [01:19<02:35,  2.73s/it, _timers/_fps=179.562, dice=0.306, loss=1.083]
# 0/50 * Epoch (train):  27% 21/78 [01:21<02:35,  2.73s/it, _timers/_fps=287.584, dice=0.308, loss=1.043]
# 0/50 * Epoch (train):  28% 22/78 [01:21<02:14,  2.41s/it, _timers/_fps=287.584, dice=0.308, loss=1.043]
# 0/50 * Epoch (train):  28% 22/78 [01:23<02:14,  2.41s/it, _timers/_fps=286.204, dice=0.306, loss=1.053]
# 0/50 * Epoch (train):  29% 23/78 [01:23<02:00,  2.19s/it, _timers/_fps=286.204, dice=0.306, loss=1.053]
# 0/50 * Epoch (train):  29% 23/78 [01:24<02:00,  2.19s/it, _timers/_fps=285.740, dice=0.327, loss=1.060]
# 0/50 * Epoch (train):  31% 24/78 [01:24<01:49,  2.03s/it, _timers/_fps=285.740, dice=0.327, loss=1.060]
# 0/50 * Epoch (train):  31% 24/78 [01:36<01:49,  2.03s/it, _timers/_fps=6.164, dice=0.319, loss=1.030]
# 0/50 * Epoch (train):  32% 25/78 [01:36<04:24,  4.99s/it, _timers/_fps=6.164, dice=0.319, loss=1.030]
# 0/50 * Epoch (train):  32% 25/78 [01:38<04:24,  4.99s/it, _timers/_fps=162.302, dice=0.324, loss=1.016]
# 0/50 * Epoch (train):  33% 26/78 [01:38<03:29,  4.04s/it, _timers/_fps=162.302, dice=0.324, loss=1.016]
# 0/50 * Epoch (train):  33% 26/78 [01:40<03:29,  4.04s/it, _timers/_fps=292.697, dice=0.325, loss=1.040]
# 0/50 * Epoch (train):  35% 27/78 [01:40<02:49,  3.32s/it, _timers/_fps=292.697, dice=0.325, loss=1.040]
# 0/50 * Epoch (train):  35% 27/78 [01:41<02:49,  3.32s/it, _timers/_fps=279.244, dice=0.366, loss=0.942]
# 0/50 * Epoch (train):  36% 28/78 [01:41<02:21,  2.83s/it, _timers/_fps=279.244, dice=0.366, loss=0.942]
# 0/50 * Epoch (train):  36% 28/78 [01:43<02:21,  2.83s/it, _timers/_fps=245.064, dice=0.366, loss=0.977]
# 0/50 * Epoch (train):  37% 29/78 [01:43<02:01,  2.49s/it, _timers/_fps=245.064, dice=0.366, loss=0.977]
# 0/50 * Epoch (train):  37% 29/78 [01:45<02:01,  2.49s/it, _timers/_fps=212.073, dice=0.388, loss=0.938]
# 0/50 * Epoch (train):  38% 30/78 [01:45<01:48,  2.26s/it, _timers/_fps=212.073, dice=0.388, loss=0.938]
# 0/50 * Epoch (train):  38% 30/78 [01:46<01:48,  2.26s/it, _timers/_fps=275.181, dice=0.381, loss=0.973]
# 0/50 * Epoch (train):  40% 31/78 [01:46<01:38,  2.09s/it, _timers/_fps=275.181, dice=0.381, loss=0.973]
# 0/50 * Epoch (train):  40% 31/78 [01:48<01:38,  2.09s/it, _timers/_fps=276.368, dice=0.351, loss=0.986]
# 0/50 * Epoch (train):  41% 32/78 [01:48<01:30,  1.97s/it, _timers/_fps=276.368, dice=0.351, loss=0.986]
# 0/50 * Epoch (train):  41% 32/78 [02:01<01:30,  1.97s/it, _timers/_fps=5.735, dice=0.400, loss=0.950]
# 0/50 * Epoch (train):  42% 33/78 [02:01<03:52,  5.16s/it, _timers/_fps=5.735, dice=0.400, loss=0.950]
# 0/50 * Epoch (train):  42% 33/78 [02:02<03:52,  5.16s/it, _timers/_fps=261.171, dice=0.389, loss=0.956]
# 0/50 * Epoch (train):  44% 34/78 [02:02<03:00,  4.11s/it, _timers/_fps=261.171, dice=0.389, loss=0.956]
# 0/50 * Epoch (train):  44% 34/78 [02:04<03:00,  4.11s/it, _timers/_fps=256.746, dice=0.374, loss=0.957]
# 0/50 * Epoch (train):  45% 35/78 [02:04<02:24,  3.37s/it, _timers/_fps=256.746, dice=0.374, loss=0.957]
# 0/50 * Epoch (train):  45% 35/78 [02:06<02:24,  3.37s/it, _timers/_fps=260.352, dice=0.385, loss=0.963]
# 0/50 * Epoch (train):  46% 36/78 [02:06<02:00,  2.86s/it, _timers/_fps=260.352, dice=0.385, loss=0.963]
# 0/50 * Epoch (train):  46% 36/78 [02:07<02:00,  2.86s/it, _timers/_fps=274.106, dice=0.430, loss=0.894]
# 0/50 * Epoch (train):  47% 37/78 [02:07<01:42,  2.50s/it, _timers/_fps=274.106, dice=0.430, loss=0.894]
# 0/50 * Epoch (train):  47% 37/78 [02:09<01:42,  2.50s/it, _timers/_fps=284.045, dice=0.390, loss=0.957]
# 0/50 * Epoch (train):  49% 38/78 [02:09<01:30,  2.25s/it, _timers/_fps=284.045, dice=0.390, loss=0.957]
# 0/50 * Epoch (train):  49% 38/78 [02:11<01:30,  2.25s/it, _timers/_fps=298.724, dice=0.408, loss=0.933]
# 0/50 * Epoch (train):  50% 39/78 [02:11<01:20,  2.07s/it, _timers/_fps=298.724, dice=0.408, loss=0.933]
# 0/50 * Epoch (train):  50% 39/78 [02:12<01:20,  2.07s/it, _timers/_fps=272.692, dice=0.397, loss=0.952]
# 0/50 * Epoch (train):  51% 40/78 [02:12<01:14,  1.95s/it, _timers/_fps=272.692, dice=0.397, loss=0.952]
# 0/50 * Epoch (train):  51% 40/78 [02:27<01:14,  1.95s/it, _timers/_fps=4.757, dice=0.446, loss=0.855]
# 0/50 * Epoch (train):  53% 41/78 [02:27<03:35,  5.84s/it, _timers/_fps=4.757, dice=0.446, loss=0.855]
# 0/50 * Epoch (train):  53% 41/78 [02:29<03:35,  5.84s/it, _timers/_fps=287.972, dice=0.429, loss=0.904]
# 0/50 * Epoch (train):  54% 42/78 [02:29<02:44,  4.58s/it, _timers/_fps=287.972, dice=0.429, loss=0.904]
# 0/50 * Epoch (train):  54% 42/78 [02:31<02:44,  4.58s/it, _timers/_fps=287.749, dice=0.432, loss=0.905]
# 0/50 * Epoch (train):  55% 43/78 [02:31<02:09,  3.71s/it, _timers/_fps=287.749, dice=0.432, loss=0.905]
# 0/50 * Epoch (train):  55% 43/78 [02:32<02:09,  3.71s/it, _timers/_fps=270.454, dice=0.435, loss=0.882]
# 0/50 * Epoch (train):  56% 44/78 [02:32<01:45,  3.10s/it, _timers/_fps=270.454, dice=0.435, loss=0.882]
# 0/50 * Epoch (train):  56% 44/78 [02:34<01:45,  3.10s/it, _timers/_fps=295.128, dice=0.415, loss=0.949]
# 0/50 * Epoch (train):  58% 45/78 [02:34<01:27,  2.66s/it, _timers/_fps=295.128, dice=0.415, loss=0.949]
# 0/50 * Epoch (train):  58% 45/78 [02:36<01:27,  2.66s/it, _timers/_fps=281.098, dice=0.417, loss=0.930]
# 0/50 * Epoch (train):  59% 46/78 [02:36<01:15,  2.36s/it, _timers/_fps=281.098, dice=0.417, loss=0.930]
# 0/50 * Epoch (train):  59% 46/78 [02:37<01:15,  2.36s/it, _timers/_fps=292.774, dice=0.445, loss=0.910]
# 0/50 * Epoch (train):  60% 47/78 [02:37<01:06,  2.15s/it, _timers/_fps=292.774, dice=0.445, loss=0.910]
# 0/50 * Epoch (train):  60% 47/78 [02:39<01:06,  2.15s/it, _timers/_fps=282.381, dice=0.442, loss=0.890]
# 0/50 * Epoch (train):  62% 48/78 [02:39<01:00,  2.00s/it, _timers/_fps=282.381, dice=0.442, loss=0.890]
# 0/50 * Epoch (train):  62% 48/78 [02:53<01:00,  2.00s/it, _timers/_fps=5.001, dice=0.461, loss=0.868]
# 0/50 * Epoch (train):  63% 49/78 [02:53<02:44,  5.68s/it, _timers/_fps=5.001, dice=0.461, loss=0.868]
# 0/50 * Epoch (train):  63% 49/78 [02:55<02:44,  5.68s/it, _timers/_fps=263.955, dice=0.400, loss=0.975]
# 0/50 * Epoch (train):  64% 50/78 [02:55<02:05,  4.48s/it, _timers/_fps=263.955, dice=0.400, loss=0.975]
# 0/50 * Epoch (train):  64% 50/78 [02:56<02:05,  4.48s/it, _timers/_fps=285.093, dice=0.406, loss=0.940]
# 0/50 * Epoch (train):  65% 51/78 [02:56<01:38,  3.64s/it, _timers/_fps=285.093, dice=0.406, loss=0.940]
# 0/50 * Epoch (train):  65% 51/78 [02:58<01:38,  3.64s/it, _timers/_fps=281.948, dice=0.429, loss=0.918]
# 0/50 * Epoch (train):  67% 52/78 [02:58<01:19,  3.05s/it, _timers/_fps=281.948, dice=0.429, loss=0.918]
# 0/50 * Epoch (train):  67% 52/78 [03:00<01:19,  3.05s/it, _timers/_fps=303.301, dice=0.448, loss=0.861]
# 0/50 * Epoch (train):  68% 53/78 [03:00<01:05,  2.63s/it, _timers/_fps=303.301, dice=0.448, loss=0.861]
# 0/50 * Epoch (train):  68% 53/78 [03:01<01:05,  2.63s/it, _timers/_fps=278.775, dice=0.446, loss=0.894]
# 0/50 * Epoch (train):  69% 54/78 [03:01<00:56,  2.34s/it, _timers/_fps=278.775, dice=0.446, loss=0.894]
# 0/50 * Epoch (train):  69% 54/78 [03:03<00:56,  2.34s/it, _timers/_fps=313.495, dice=0.482, loss=0.837]
# 0/50 * Epoch (train):  71% 55/78 [03:03<00:48,  2.13s/it, _timers/_fps=313.495, dice=0.482, loss=0.837]
# 0/50 * Epoch (train):  71% 55/78 [03:05<00:48,  2.13s/it, _timers/_fps=283.062, dice=0.409, loss=0.964]
# 0/50 * Epoch (train):  72% 56/78 [03:05<00:43,  1.99s/it, _timers/_fps=283.062, dice=0.409, loss=0.964]
# 0/50 * Epoch (train):  72% 56/78 [03:20<00:43,  1.99s/it, _timers/_fps=4.753, dice=0.447, loss=0.895]
# 0/50 * Epoch (train):  73% 57/78 [03:20<02:03,  5.87s/it, _timers/_fps=4.753, dice=0.447, loss=0.895]
# 0/50 * Epoch (train):  73% 57/78 [03:21<02:03,  5.87s/it, _timers/_fps=261.133, dice=0.407, loss=0.950]
# 0/50 * Epoch (train):  74% 58/78 [03:21<01:32,  4.61s/it, _timers/_fps=261.133, dice=0.407, loss=0.950]
# 0/50 * Epoch (train):  74% 58/78 [03:23<01:32,  4.61s/it, _timers/_fps=259.435, dice=0.414, loss=0.942]
# 0/50 * Epoch (train):  76% 59/78 [03:23<01:10,  3.72s/it, _timers/_fps=259.435, dice=0.414, loss=0.942]
# 0/50 * Epoch (train):  76% 59/78 [03:25<01:10,  3.72s/it, _timers/_fps=293.434, dice=0.447, loss=0.877]
# 0/50 * Epoch (train):  77% 60/78 [03:25<00:55,  3.10s/it, _timers/_fps=293.434, dice=0.447, loss=0.877]
# 0/50 * Epoch (train):  77% 60/78 [03:26<00:55,  3.10s/it, _timers/_fps=292.894, dice=0.424, loss=0.899]
# 0/50 * Epoch (train):  78% 61/78 [03:26<00:45,  2.67s/it, _timers/_fps=292.894, dice=0.424, loss=0.899]
# 0/50 * Epoch (train):  78% 61/78 [03:28<00:45,  2.67s/it, _timers/_fps=295.492, dice=0.422, loss=0.925]
# 0/50 * Epoch (train):  79% 62/78 [03:28<00:37,  2.37s/it, _timers/_fps=295.492, dice=0.422, loss=0.925]
# 0/50 * Epoch (train):  79% 62/78 [03:30<00:37,  2.37s/it, _timers/_fps=252.786, dice=0.434, loss=0.881]
# 0/50 * Epoch (train):  81% 63/78 [03:30<00:32,  2.17s/it, _timers/_fps=252.786, dice=0.434, loss=0.881]
# 0/50 * Epoch (train):  81% 63/78 [03:31<00:32,  2.17s/it, _timers/_fps=266.759, dice=0.412, loss=0.934]
# 0/50 * Epoch (train):  82% 64/78 [03:31<00:28,  2.02s/it, _timers/_fps=266.759, dice=0.412, loss=0.934]
# 0/50 * Epoch (train):  82% 64/78 [03:46<00:28,  2.02s/it, _timers/_fps=4.847, dice=0.421, loss=0.919]
# 0/50 * Epoch (train):  83% 65/78 [03:46<01:15,  5.80s/it, _timers/_fps=4.847, dice=0.421, loss=0.919]
# 0/50 * Epoch (train):  83% 65/78 [03:48<01:15,  5.80s/it, _timers/_fps=234.121, dice=0.430, loss=0.922]
# 0/50 * Epoch (train):  85% 66/78 [03:48<00:54,  4.57s/it, _timers/_fps=234.121, dice=0.430, loss=0.922]
# 0/50 * Epoch (train):  85% 66/78 [03:49<00:54,  4.57s/it, _timers/_fps=312.779, dice=0.444, loss=0.922]
# 0/50 * Epoch (train):  86% 67/78 [03:49<00:40,  3.69s/it, _timers/_fps=312.779, dice=0.444, loss=0.922]
# 0/50 * Epoch (train):  86% 67/78 [03:51<00:40,  3.69s/it, _timers/_fps=329.974, dice=0.435, loss=0.913]
# 0/50 * Epoch (train):  87% 68/78 [03:51<00:30,  3.07s/it, _timers/_fps=329.974, dice=0.435, loss=0.913]
# 0/50 * Epoch (train):  87% 68/78 [03:53<00:30,  3.07s/it, _timers/_fps=301.767, dice=0.452, loss=0.884]
# 0/50 * Epoch (train):  88% 69/78 [03:53<00:23,  2.64s/it, _timers/_fps=301.767, dice=0.452, loss=0.884]
# 0/50 * Epoch (train):  88% 69/78 [03:54<00:23,  2.64s/it, _timers/_fps=321.940, dice=0.432, loss=0.900]
# 0/50 * Epoch (train):  90% 70/78 [03:54<00:18,  2.34s/it, _timers/_fps=321.940, dice=0.432, loss=0.900]
# 0/50 * Epoch (train):  90% 70/78 [03:56<00:18,  2.34s/it, _timers/_fps=293.115, dice=0.418, loss=0.931]
# 0/50 * Epoch (train):  91% 71/78 [03:56<00:14,  2.13s/it, _timers/_fps=293.115, dice=0.418, loss=0.931]
# 0/50 * Epoch (train):  91% 71/78 [03:57<00:14,  2.13s/it, _timers/_fps=288.627, dice=0.429, loss=0.929]
# 0/50 * Epoch (train):  92% 72/78 [03:57<00:11,  1.98s/it, _timers/_fps=288.627, dice=0.429, loss=0.929]
# 0/50 * Epoch (train):  92% 72/78 [04:09<00:11,  1.98s/it, _timers/_fps=6.490, dice=0.487, loss=0.821]
# 0/50 * Epoch (train):  94% 73/78 [04:09<00:23,  4.78s/it, _timers/_fps=6.490, dice=0.487, loss=0.821]
# 0/50 * Epoch (train):  94% 73/78 [04:10<00:23,  4.78s/it, _timers/_fps=382.787, dice=0.428, loss=0.895]
# 0/50 * Epoch (train):  95% 74/78 [04:10<00:15,  3.83s/it, _timers/_fps=382.787, dice=0.428, loss=0.895]
# 0/50 * Epoch (train):  95% 74/78 [04:12<00:15,  3.83s/it, _timers/_fps=384.094, dice=0.453, loss=0.857]
# 0/50 * Epoch (train):  96% 75/78 [04:12<00:09,  3.16s/it, _timers/_fps=384.094, dice=0.453, loss=0.857]
# 0/50 * Epoch (train):  96% 75/78 [04:14<00:09,  3.16s/it, _timers/_fps=374.663, dice=0.469, loss=0.863]
# 0/50 * Epoch (train):  97% 76/78 [04:14<00:05,  2.69s/it, _timers/_fps=374.663, dice=0.469, loss=0.863]
# 0/50 * Epoch (train):  97% 76/78 [04:15<00:05,  2.69s/it, _timers/_fps=380.349, dice=0.415, loss=0.928]
# 0/50 * Epoch (train):  99% 77/78 [04:15<00:02,  2.36s/it, _timers/_fps=380.349, dice=0.415, loss=0.928]
# 0/50 * Epoch (train):  99% 77/78 [04:17<00:02,  2.36s/it, _timers/_fps=378.775, dice=0.470, loss=0.818]
# 0/50 * Epoch (train): 100% 78/78 [04:17<00:00,  3.30s/it, _timers/_fps=378.775, dice=0.470, loss=0.818]
#
# 0/50 * Epoch (valid):   0% 0/9 [00:00<?, ?it/s]
# 0/50 * Epoch (valid):   0% 0/9 [00:11<?, ?it/s, _timers/_fps=5.751, dice=0.448, loss=1.027]
# 0/50 * Epoch (valid):  11% 1/9 [00:11<01:31, 11.49s/it, _timers/_fps=5.751, dice=0.448, loss=1.027]
# 0/50 * Epoch (valid):  11% 1/9 [00:12<01:31, 11.49s/it, _timers/_fps=292.900, dice=0.442, loss=1.029]
# 0/50 * Epoch (valid):  22% 2/9 [00:12<00:57,  8.22s/it, _timers/_fps=292.900, dice=0.442, loss=1.029]
# 0/50 * Epoch (valid):  22% 2/9 [00:12<00:57,  8.22s/it, _timers/_fps=398.903, dice=0.482, loss=0.942]
# 0/50 * Epoch (valid):  33% 3/9 [00:12<00:35,  5.92s/it, _timers/_fps=398.903, dice=0.482, loss=0.942]
# 0/50 * Epoch (valid):  33% 3/9 [00:13<00:35,  5.92s/it, _timers/_fps=398.727, dice=0.485, loss=0.968]
# 0/50 * Epoch (valid):  44% 4/9 [00:13<00:21,  4.30s/it, _timers/_fps=398.727, dice=0.485, loss=0.968]
# 0/50 * Epoch (valid):  44% 4/9 [00:13<00:21,  4.30s/it, _timers/_fps=393.867, dice=0.460, loss=0.990]
# 0/50 * Epoch (valid):  56% 5/9 [00:13<00:12,  3.18s/it, _timers/_fps=393.867, dice=0.460, loss=0.990]
# 0/50 * Epoch (valid):  56% 5/9 [00:14<00:12,  3.18s/it, _timers/_fps=401.792, dice=0.491, loss=0.959]
# 0/50 * Epoch (valid):  67% 6/9 [00:14<00:07,  2.38s/it, _timers/_fps=401.792, dice=0.491, loss=0.959]
# 0/50 * Epoch (valid):  67% 6/9 [00:14<00:07,  2.38s/it, _timers/_fps=398.922, dice=0.503, loss=0.969]
# 0/50 * Epoch (valid):  78% 7/9 [00:14<00:03,  1.83s/it, _timers/_fps=398.922, dice=0.503, loss=0.969]
# 0/50 * Epoch (valid):  78% 7/9 [00:15<00:03,  1.83s/it, _timers/_fps=404.891, dice=0.488, loss=0.980]
# 0/50 * Epoch (valid):  89% 8/9 [00:15<00:01,  1.44s/it, _timers/_fps=404.891, dice=0.488, loss=0.980]
# 0/50 * Epoch (valid):  89% 8/9 [00:17<00:01,  1.44s/it, _timers/_fps=32.364, dice=0.455, loss=0.997]
# 0/50 * Epoch (valid): 100% 9/9 [00:17<00:00,  1.97s/it, _timers/_fps=32.364, dice=0.455, loss=0.997]
# [2019-10-30 18:49:10,957]
# 0/50 * Epoch 0 (train): _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=238.8768 | _timers/batch_time=1.8598 | _timers/data_time=1.8241 | _timers/model_time=0.0356 | dice=0.3735 | loss=1.0103
# 0/50 * Epoch 0 (valid): _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=303.1241 | _timers/batch_time=1.5874 | _timers/data_time=1.5696 | _timers/model_time=0.0177 | dice=0.4726 | loss=0.9847
# [2019-10-30 18:49:10,957]
# 0/50 * Epoch 0 (train): _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=238.8768 | _timers/batch_time=1.8598 | _timers/data_time=1.8241 | _timers/model_time=0.0356 | dice=0.3735 | loss=1.0103
# 0/50 * Epoch 0 (valid): _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=303.1241 | _timers/batch_time=1.5874 | _timers/data_time=1.5696 | _timers/model_time=0.0177 | dice=0.4726 | loss=0.9847
#
# 1/50 * Epoch (train):   0% 0/78 [00:00<?, ?it/s]
# 1/50 * Epoch (train):   0% 0/78 [00:24<?, ?it/s, _timers/_fps=2.715, dice=0.459, loss=0.862]
# 1/50 * Epoch (train):   1% 1/78 [00:24<32:04, 25.00s/it, _timers/_fps=2.715, dice=0.459, loss=0.862]
# 1/50 * Epoch (train):   1% 1/78 [00:26<32:04, 25.00s/it, _timers/_fps=306.821, dice=0.441, loss=0.911]
# 1/50 * Epoch (train):   3% 2/78 [00:26<22:47, 17.99s/it, _timers/_fps=306.821, dice=0.441, loss=0.911]
# 1/50 * Epoch (train):   3% 2/78 [00:28<22:47, 17.99s/it, _timers/_fps=176.154, dice=0.448, loss=0.889]
# 1/50 * Epoch (train):   4% 3/78 [00:28<16:24, 13.13s/it, _timers/_fps=176.154, dice=0.448, loss=0.889]
# 1/50 * Epoch (train):   4% 3/78 [00:30<16:24, 13.13s/it, _timers/_fps=295.406, dice=0.455, loss=0.880]
# 1/50 * Epoch (train):   5% 4/78 [00:30<11:57,  9.69s/it, _timers/_fps=295.406, dice=0.455, loss=0.880]
# 1/50 * Epoch (train):   5% 4/78 [00:31<11:57,  9.69s/it, _timers/_fps=293.171, dice=0.405, loss=0.940]
# 1/50 * Epoch (train):   6% 5/78 [00:31<08:51,  7.29s/it, _timers/_fps=293.171, dice=0.405, loss=0.940]
# 1/50 * Epoch (train):   6% 5/78 [00:33<08:51,  7.29s/it, _timers/_fps=296.978, dice=0.426, loss=0.929]
# 1/50 * Epoch (train):   8% 6/78 [00:33<06:42,  5.60s/it, _timers/_fps=296.978, dice=0.426, loss=0.929]
# 1/50 * Epoch (train):   8% 6/78 [00:35<06:42,  5.60s/it, _timers/_fps=227.813, dice=0.487, loss=0.848]
# 1/50 * Epoch (train):   9% 7/78 [00:35<05:15,  4.45s/it, _timers/_fps=227.813, dice=0.487, loss=0.848]
# 1/50 * Epoch (train):   9% 7/78 [00:36<05:15,  4.45s/it, _timers/_fps=260.156, dice=0.449, loss=0.890]
# 1/50 * Epoch (train):  10% 8/78 [00:36<04:13,  3.62s/it, _timers/_fps=260.156, dice=0.449, loss=0.890]
# 1/50 * Epoch (train):  10% 8/78 [00:49<04:13,  3.62s/it, _timers/_fps=5.535, dice=0.463, loss=0.871]
# 1/50 * Epoch (train):  12% 9/78 [00:49<07:23,  6.43s/it, _timers/_fps=5.535, dice=0.463, loss=0.871]
# 1/50 * Epoch (train):  12% 9/78 [00:51<07:23,  6.43s/it, _timers/_fps=225.771, dice=0.450, loss=0.896]
# 1/50 * Epoch (train):  13% 10/78 [00:51<05:40,  5.01s/it, _timers/_fps=225.771, dice=0.450, loss=0.896]
# 1/50 * Epoch (train):  13% 10/78 [00:53<05:40,  5.01s/it, _timers/_fps=287.855, dice=0.405, loss=0.892]
# 1/50 * Epoch (train):  14% 11/78 [00:53<04:28,  4.00s/it, _timers/_fps=287.855, dice=0.405, loss=0.892]
# 1/50 * Epoch (train):  14% 11/78 [00:54<04:28,  4.00s/it, _timers/_fps=292.563, dice=0.446, loss=0.905]
# 1/50 * Epoch (train):  15% 12/78 [00:54<03:38,  3.31s/it, _timers/_fps=292.563, dice=0.446, loss=0.905]
# 1/50 * Epoch (train):  15% 12/78 [00:56<03:38,  3.31s/it, _timers/_fps=296.028, dice=0.487, loss=0.792]
# 1/50 * Epoch (train):  17% 13/78 [00:56<03:03,  2.82s/it, _timers/_fps=296.028, dice=0.487, loss=0.792]
# 1/50 * Epoch (train):  17% 13/78 [00:58<03:03,  2.82s/it, _timers/_fps=274.373, dice=0.472, loss=0.821]
# 1/50 * Epoch (train):  18% 14/78 [00:58<02:39,  2.48s/it, _timers/_fps=274.373, dice=0.472, loss=0.821]
# 1/50 * Epoch (train):  18% 14/78 [01:00<02:39,  2.48s/it, _timers/_fps=141.231, dice=0.469, loss=0.831]
# 1/50 * Epoch (train):  19% 15/78 [01:00<02:24,  2.29s/it, _timers/_fps=141.231, dice=0.469, loss=0.831]
# 1/50 * Epoch (train):  19% 15/78 [01:01<02:24,  2.29s/it, _timers/_fps=205.579, dice=0.424, loss=0.891]
# 1/50 * Epoch (train):  21% 16/78 [01:01<02:12,  2.13s/it, _timers/_fps=205.579, dice=0.424, loss=0.891]
# 1/50 * Epoch (train):  21% 16/78 [01:14<02:12,  2.13s/it, _timers/_fps=5.997, dice=0.476, loss=0.810]
# 1/50 * Epoch (train):  22% 17/78 [01:14<05:13,  5.14s/it, _timers/_fps=5.997, dice=0.476, loss=0.810]
# 1/50 * Epoch (train):  22% 17/78 [01:15<05:13,  5.14s/it, _timers/_fps=156.325, dice=0.459, loss=0.857]
# 1/50 * Epoch (train):  23% 18/78 [01:15<04:08,  4.14s/it, _timers/_fps=156.325, dice=0.459, loss=0.857]
# 1/50 * Epoch (train):  23% 18/78 [01:17<04:08,  4.14s/it, _timers/_fps=237.687, dice=0.453, loss=0.918]
# 1/50 * Epoch (train):  24% 19/78 [01:17<03:21,  3.41s/it, _timers/_fps=237.687, dice=0.453, loss=0.918]
# 1/50 * Epoch (train):  24% 19/78 [01:19<03:21,  3.41s/it, _timers/_fps=204.039, dice=0.476, loss=0.840]
# 1/50 * Epoch (train):  26% 20/78 [01:19<02:48,  2.91s/it, _timers/_fps=204.039, dice=0.476, loss=0.840]
# 1/50 * Epoch (train):  26% 20/78 [01:21<02:48,  2.91s/it, _timers/_fps=160.646, dice=0.461, loss=0.894]
# 1/50 * Epoch (train):  27% 21/78 [01:21<02:26,  2.57s/it, _timers/_fps=160.646, dice=0.461, loss=0.894]
# 1/50 * Epoch (train):  27% 21/78 [01:22<02:26,  2.57s/it, _timers/_fps=245.935, dice=0.470, loss=0.852]
# 1/50 * Epoch (train):  28% 22/78 [01:22<02:09,  2.31s/it, _timers/_fps=245.935, dice=0.470, loss=0.852]
# 1/50 * Epoch (train):  28% 22/78 [01:24<02:09,  2.31s/it, _timers/_fps=240.434, dice=0.461, loss=0.908]
# 1/50 * Epoch (train):  29% 23/78 [01:24<01:56,  2.11s/it, _timers/_fps=240.434, dice=0.461, loss=0.908]
# 1/50 * Epoch (train):  29% 23/78 [01:26<01:56,  2.11s/it, _timers/_fps=252.128, dice=0.480, loss=0.822]
# 1/50 * Epoch (train):  31% 24/78 [01:26<01:47,  1.98s/it, _timers/_fps=252.128, dice=0.480, loss=0.822]
# 1/50 * Epoch (train):  31% 24/78 [01:36<01:47,  1.98s/it, _timers/_fps=7.437, dice=0.461, loss=0.908]
# 1/50 * Epoch (train):  32% 25/78 [01:36<03:53,  4.40s/it, _timers/_fps=7.437, dice=0.461, loss=0.908]
# 1/50 * Epoch (train):  32% 25/78 [01:37<03:53,  4.40s/it, _timers/_fps=288.251, dice=0.469, loss=0.875]
# 1/50 * Epoch (train):  33% 26/78 [01:37<03:06,  3.58s/it, _timers/_fps=288.251, dice=0.469, loss=0.875]
# 1/50 * Epoch (train):  33% 26/78 [01:39<03:06,  3.58s/it, _timers/_fps=205.372, dice=0.462, loss=0.852]
# 1/50 * Epoch (train):  35% 27/78 [01:39<02:35,  3.05s/it, _timers/_fps=205.372, dice=0.462, loss=0.852]
# 1/50 * Epoch (train):  35% 27/78 [01:41<02:35,  3.05s/it, _timers/_fps=146.591, dice=0.451, loss=0.899]
# 1/50 * Epoch (train):  36% 28/78 [01:41<02:14,  2.69s/it, _timers/_fps=146.591, dice=0.451, loss=0.899]
# 1/50 * Epoch (train):  36% 28/78 [01:43<02:14,  2.69s/it, _timers/_fps=283.031, dice=0.463, loss=0.833]
# 1/50 * Epoch (train):  37% 29/78 [01:43<01:57,  2.39s/it, _timers/_fps=283.031, dice=0.463, loss=0.833]
# 1/50 * Epoch (train):  37% 29/78 [01:44<01:57,  2.39s/it, _timers/_fps=269.675, dice=0.456, loss=0.854]
# 1/50 * Epoch (train):  38% 30/78 [01:44<01:45,  2.19s/it, _timers/_fps=269.675, dice=0.456, loss=0.854]
# 1/50 * Epoch (train):  38% 30/78 [01:46<01:45,  2.19s/it, _timers/_fps=139.763, dice=0.422, loss=0.925]
# 1/50 * Epoch (train):  40% 31/78 [01:46<01:39,  2.11s/it, _timers/_fps=139.763, dice=0.422, loss=0.925]
# 1/50 * Epoch (train):  40% 31/78 [01:48<01:39,  2.11s/it, _timers/_fps=144.457, dice=0.466, loss=0.846]
# 1/50 * Epoch (train):  41% 32/78 [01:48<01:33,  2.04s/it, _timers/_fps=144.457, dice=0.466, loss=0.846]
# 1/50 * Epoch (train):  41% 32/78 [01:58<01:33,  2.04s/it, _timers/_fps=7.831, dice=0.471, loss=0.834]
# 1/50 * Epoch (train):  42% 33/78 [01:58<03:14,  4.32s/it, _timers/_fps=7.831, dice=0.471, loss=0.834]
# 1/50 * Epoch (train):  42% 33/78 [02:00<03:14,  4.32s/it, _timers/_fps=276.454, dice=0.458, loss=0.850]
# 1/50 * Epoch (train):  44% 34/78 [02:00<02:35,  3.52s/it, _timers/_fps=276.454, dice=0.458, loss=0.850]
# 1/50 * Epoch (train):  44% 34/78 [02:01<02:35,  3.52s/it, _timers/_fps=219.491, dice=0.461, loss=0.838]
# 1/50 * Epoch (train):  45% 35/78 [02:01<02:07,  2.97s/it, _timers/_fps=219.491, dice=0.461, loss=0.838]
# 1/50 * Epoch (train):  45% 35/78 [02:03<02:07,  2.97s/it, _timers/_fps=276.737, dice=0.466, loss=0.842]
# 1/50 * Epoch (train):  46% 36/78 [02:03<01:48,  2.58s/it, _timers/_fps=276.737, dice=0.466, loss=0.842]
# 1/50 * Epoch (train):  46% 36/78 [02:05<01:48,  2.58s/it, _timers/_fps=176.060, dice=0.447, loss=0.870]
# 1/50 * Epoch (train):  47% 37/78 [02:05<01:36,  2.35s/it, _timers/_fps=176.060, dice=0.447, loss=0.870]
# 1/50 * Epoch (train):  47% 37/78 [02:06<01:36,  2.35s/it, _timers/_fps=198.242, dice=0.461, loss=0.863]
# 1/50 * Epoch (train):  49% 38/78 [02:06<01:27,  2.18s/it, _timers/_fps=198.242, dice=0.461, loss=0.863]
# 1/50 * Epoch (train):  49% 38/78 [02:08<01:27,  2.18s/it, _timers/_fps=140.740, dice=0.480, loss=0.831]
# 1/50 * Epoch (train):  50% 39/78 [02:08<01:21,  2.09s/it, _timers/_fps=140.740, dice=0.480, loss=0.831]
# 1/50 * Epoch (train):  50% 39/78 [02:10<01:21,  2.09s/it, _timers/_fps=275.757, dice=0.470, loss=0.841]
# 1/50 * Epoch (train):  51% 40/78 [02:10<01:14,  1.97s/it, _timers/_fps=275.757, dice=0.470, loss=0.841]
# 1/50 * Epoch (train):  51% 40/78 [02:21<01:14,  1.97s/it, _timers/_fps=6.433, dice=0.487, loss=0.826]
# 1/50 * Epoch (train):  53% 41/78 [02:21<02:57,  4.79s/it, _timers/_fps=6.433, dice=0.487, loss=0.826]
# 1/50 * Epoch (train):  53% 41/78 [02:23<02:57,  4.79s/it, _timers/_fps=218.507, dice=0.464, loss=0.882]
# 1/50 * Epoch (train):  54% 42/78 [02:23<02:19,  3.87s/it, _timers/_fps=218.507, dice=0.464, loss=0.882]
# 1/50 * Epoch (train):  54% 42/78 [02:25<02:19,  3.87s/it, _timers/_fps=270.224, dice=0.483, loss=0.842]
# 1/50 * Epoch (train):  55% 43/78 [02:25<01:52,  3.22s/it, _timers/_fps=270.224, dice=0.483, loss=0.842]
# 1/50 * Epoch (train):  55% 43/78 [02:27<01:52,  3.22s/it, _timers/_fps=199.208, dice=0.474, loss=0.864]
# 1/50 * Epoch (train):  56% 44/78 [02:27<01:34,  2.78s/it, _timers/_fps=199.208, dice=0.474, loss=0.864]
# 1/50 * Epoch (train):  56% 44/78 [02:28<01:34,  2.78s/it, _timers/_fps=277.586, dice=0.459, loss=0.909]
# 1/50 * Epoch (train):  58% 45/78 [02:28<01:20,  2.45s/it, _timers/_fps=277.586, dice=0.459, loss=0.909]
# 1/50 * Epoch (train):  58% 45/78 [02:30<01:20,  2.45s/it, _timers/_fps=264.735, dice=0.455, loss=0.872]
# 1/50 * Epoch (train):  59% 46/78 [02:30<01:10,  2.22s/it, _timers/_fps=264.735, dice=0.455, loss=0.872]
# 1/50 * Epoch (train):  59% 46/78 [02:32<01:10,  2.22s/it, _timers/_fps=284.042, dice=0.495, loss=0.791]
# 1/50 * Epoch (train):  60% 47/78 [02:32<01:03,  2.06s/it, _timers/_fps=284.042, dice=0.495, loss=0.791]
# 1/50 * Epoch (train):  60% 47/78 [02:33<01:03,  2.06s/it, _timers/_fps=280.930, dice=0.433, loss=0.922]
# 1/50 * Epoch (train):  62% 48/78 [02:33<00:58,  1.94s/it, _timers/_fps=280.930, dice=0.433, loss=0.922]
# 1/50 * Epoch (train):  62% 48/78 [02:44<00:58,  1.94s/it, _timers/_fps=7.147, dice=0.486, loss=0.796]
# 1/50 * Epoch (train):  63% 49/78 [02:44<02:10,  4.49s/it, _timers/_fps=7.147, dice=0.486, loss=0.796]
# 1/50 * Epoch (train):  63% 49/78 [02:46<02:10,  4.49s/it, _timers/_fps=53.163, dice=0.426, loss=0.903]
# 1/50 * Epoch (train):  64% 50/78 [02:46<01:50,  3.93s/it, _timers/_fps=53.163, dice=0.426, loss=0.903]
# 1/50 * Epoch (train):  64% 50/78 [02:48<01:50,  3.93s/it, _timers/_fps=158.174, dice=0.465, loss=0.862]
# 1/50 * Epoch (train):  65% 51/78 [02:48<01:29,  3.31s/it, _timers/_fps=158.174, dice=0.465, loss=0.862]
# 1/50 * Epoch (train):  65% 51/78 [02:50<01:29,  3.31s/it, _timers/_fps=288.068, dice=0.454, loss=0.867]
# 1/50 * Epoch (train):  67% 52/78 [02:50<01:13,  2.82s/it, _timers/_fps=288.068, dice=0.454, loss=0.867]
# 1/50 * Epoch (train):  67% 52/78 [02:52<01:13,  2.82s/it, _timers/_fps=259.054, dice=0.453, loss=0.865]
# 1/50 * Epoch (train):  68% 53/78 [02:52<01:02,  2.49s/it, _timers/_fps=259.054, dice=0.453, loss=0.865]
# 1/50 * Epoch (train):  68% 53/78 [02:53<01:02,  2.49s/it, _timers/_fps=241.478, dice=0.447, loss=0.854]
# 1/50 * Epoch (train):  69% 54/78 [02:53<00:54,  2.26s/it, _timers/_fps=241.478, dice=0.447, loss=0.854]
# 1/50 * Epoch (train):  69% 54/78 [02:55<00:54,  2.26s/it, _timers/_fps=103.627, dice=0.446, loss=0.866]
# 1/50 * Epoch (train):  71% 55/78 [02:55<00:50,  2.20s/it, _timers/_fps=103.627, dice=0.446, loss=0.866]
# 1/50 * Epoch (train):  71% 55/78 [02:57<00:50,  2.20s/it, _timers/_fps=209.778, dice=0.468, loss=0.866]
# 1/50 * Epoch (train):  72% 56/78 [02:57<00:45,  2.07s/it, _timers/_fps=209.778, dice=0.468, loss=0.866]
# 1/50 * Epoch (train):  72% 56/78 [03:07<00:45,  2.07s/it, _timers/_fps=7.752, dice=0.465, loss=0.882]
# 1/50 * Epoch (train):  73% 57/78 [03:07<01:31,  4.36s/it, _timers/_fps=7.752, dice=0.465, loss=0.882]
# 1/50 * Epoch (train):  73% 57/78 [03:09<01:31,  4.36s/it, _timers/_fps=157.569, dice=0.441, loss=0.881]
# 1/50 * Epoch (train):  74% 58/78 [03:09<01:11,  3.60s/it, _timers/_fps=157.569, dice=0.441, loss=0.881]
# 1/50 * Epoch (train):  74% 58/78 [03:10<01:11,  3.60s/it, _timers/_fps=292.465, dice=0.463, loss=0.850]
# 1/50 * Epoch (train):  76% 59/78 [03:10<00:57,  3.02s/it, _timers/_fps=292.465, dice=0.463, loss=0.850]
# 1/50 * Epoch (train):  76% 59/78 [03:12<00:57,  3.02s/it, _timers/_fps=291.158, dice=0.471, loss=0.813]
# 1/50 * Epoch (train):  77% 60/78 [03:12<00:47,  2.61s/it, _timers/_fps=291.158, dice=0.471, loss=0.813]
# 1/50 * Epoch (train):  77% 60/78 [03:14<00:47,  2.61s/it, _timers/_fps=267.621, dice=0.453, loss=0.866]
# 1/50 * Epoch (train):  78% 61/78 [03:14<00:39,  2.35s/it, _timers/_fps=267.621, dice=0.453, loss=0.866]
# 1/50 * Epoch (train):  78% 61/78 [03:16<00:39,  2.35s/it, _timers/_fps=180.476, dice=0.482, loss=0.830]
# 1/50 * Epoch (train):  79% 62/78 [03:16<00:34,  2.18s/it, _timers/_fps=180.476, dice=0.482, loss=0.830]
# 1/50 * Epoch (train):  79% 62/78 [03:20<00:34,  2.18s/it, _timers/_fps=19.953, dice=0.489, loss=0.863]
# 1/50 * Epoch (train):  81% 63/78 [03:20<00:43,  2.91s/it, _timers/_fps=19.953, dice=0.489, loss=0.863]
# 1/50 * Epoch (train):  81% 63/78 [03:22<00:43,  2.91s/it, _timers/_fps=270.653, dice=0.463, loss=0.856]
# 1/50 * Epoch (train):  82% 64/78 [03:22<00:35,  2.54s/it, _timers/_fps=270.653, dice=0.463, loss=0.856]
# 1/50 * Epoch (train):  82% 64/78 [03:29<00:35,  2.54s/it, _timers/_fps=12.171, dice=0.473, loss=0.840]
# 1/50 * Epoch (train):  83% 65/78 [03:29<00:49,  3.81s/it, _timers/_fps=12.171, dice=0.473, loss=0.840]
# 1/50 * Epoch (train):  83% 65/78 [03:31<00:49,  3.81s/it, _timers/_fps=127.485, dice=0.460, loss=0.897]
# 1/50 * Epoch (train):  85% 66/78 [03:31<00:39,  3.26s/it, _timers/_fps=127.485, dice=0.460, loss=0.897]
# 1/50 * Epoch (train):  85% 66/78 [03:32<00:39,  3.26s/it, _timers/_fps=149.011, dice=0.467, loss=0.879]
# 1/50 * Epoch (train):  86% 67/78 [03:32<00:31,  2.84s/it, _timers/_fps=149.011, dice=0.467, loss=0.879]
# 1/50 * Epoch (train):  86% 67/78 [03:34<00:31,  2.84s/it, _timers/_fps=226.041, dice=0.453, loss=0.888]
# 1/50 * Epoch (train):  87% 68/78 [03:34<00:25,  2.50s/it, _timers/_fps=226.041, dice=0.453, loss=0.888]
# 1/50 * Epoch (train):  87% 68/78 [03:36<00:25,  2.50s/it, _timers/_fps=183.045, dice=0.486, loss=0.833]
# 1/50 * Epoch (train):  88% 69/78 [03:36<00:20,  2.29s/it, _timers/_fps=183.045, dice=0.486, loss=0.833]
# 1/50 * Epoch (train):  88% 69/78 [03:38<00:20,  2.29s/it, _timers/_fps=247.631, dice=0.467, loss=0.881]
# 1/50 * Epoch (train):  90% 70/78 [03:38<00:16,  2.11s/it, _timers/_fps=247.631, dice=0.467, loss=0.881]
# 1/50 * Epoch (train):  90% 70/78 [03:44<00:16,  2.11s/it, _timers/_fps=12.678, dice=0.469, loss=0.854]
# 1/50 * Epoch (train):  91% 71/78 [03:44<00:23,  3.43s/it, _timers/_fps=12.678, dice=0.469, loss=0.854]
# 1/50 * Epoch (train):  91% 71/78 [03:47<00:23,  3.43s/it, _timers/_fps=57.173, dice=0.510, loss=0.793]
# 1/50 * Epoch (train):  92% 72/78 [03:47<00:18,  3.16s/it, _timers/_fps=57.173, dice=0.510, loss=0.793]
# 1/50 * Epoch (train):  92% 72/78 [03:52<00:18,  3.16s/it, _timers/_fps=17.457, dice=0.445, loss=0.923]
# 1/50 * Epoch (train):  94% 73/78 [03:52<00:18,  3.74s/it, _timers/_fps=17.457, dice=0.445, loss=0.923]
# 1/50 * Epoch (train):  94% 73/78 [03:53<00:18,  3.74s/it, _timers/_fps=394.487, dice=0.471, loss=0.858]
# 1/50 * Epoch (train):  95% 74/78 [03:53<00:12,  3.10s/it, _timers/_fps=394.487, dice=0.471, loss=0.858]
# 1/50 * Epoch (train):  95% 74/78 [03:55<00:12,  3.10s/it, _timers/_fps=392.375, dice=0.498, loss=0.796]
# 1/50 * Epoch (train):  96% 75/78 [03:55<00:07,  2.65s/it, _timers/_fps=392.375, dice=0.498, loss=0.796]
# 1/50 * Epoch (train):  96% 75/78 [03:57<00:07,  2.65s/it, _timers/_fps=388.796, dice=0.467, loss=0.883]
# 1/50 * Epoch (train):  97% 76/78 [03:57<00:04,  2.33s/it, _timers/_fps=388.796, dice=0.467, loss=0.883]
# 1/50 * Epoch (train):  97% 76/78 [03:58<00:04,  2.33s/it, _timers/_fps=372.507, dice=0.468, loss=0.825]
# 1/50 * Epoch (train):  99% 77/78 [03:58<00:02,  2.11s/it, _timers/_fps=372.507, dice=0.468, loss=0.825]
# 1/50 * Epoch (train):  99% 77/78 [04:00<00:02,  2.11s/it, _timers/_fps=391.794, dice=0.459, loss=0.863]
# 1/50 * Epoch (train): 100% 78/78 [04:00<00:00,  3.08s/it, _timers/_fps=391.794, dice=0.459, loss=0.863]
#
# 1/50 * Epoch (valid):   0% 0/9 [00:00<?, ?it/s]
# 1/50 * Epoch (valid):   0% 0/9 [00:09<?, ?it/s, _timers/_fps=6.700, dice=0.487, loss=0.893]
# 1/50 * Epoch (valid):  11% 1/9 [00:09<01:19,  9.93s/it, _timers/_fps=6.700, dice=0.487, loss=0.893]
# 1/50 * Epoch (valid):  11% 1/9 [00:10<01:19,  9.93s/it, _timers/_fps=414.968, dice=0.454, loss=0.936]
# 1/50 * Epoch (valid):  22% 2/9 [00:10<00:49,  7.11s/it, _timers/_fps=414.968, dice=0.454, loss=0.936]
# 1/50 * Epoch (valid):  22% 2/9 [00:10<00:49,  7.11s/it, _timers/_fps=404.125, dice=0.495, loss=0.857]
# 1/50 * Epoch (valid):  33% 3/9 [00:10<00:30,  5.14s/it, _timers/_fps=404.125, dice=0.495, loss=0.857]
# 1/50 * Epoch (valid):  33% 3/9 [00:11<00:30,  5.14s/it, _timers/_fps=407.410, dice=0.495, loss=0.876]
# 1/50 * Epoch (valid):  44% 4/9 [00:11<00:18,  3.76s/it, _timers/_fps=407.410, dice=0.495, loss=0.876]
# 1/50 * Epoch (valid):  44% 4/9 [00:12<00:18,  3.76s/it, _timers/_fps=406.983, dice=0.477, loss=0.902]
# 1/50 * Epoch (valid):  56% 5/9 [00:12<00:11,  2.79s/it, _timers/_fps=406.983, dice=0.477, loss=0.902]
# 1/50 * Epoch (valid):  56% 5/9 [00:12<00:11,  2.79s/it, _timers/_fps=408.909, dice=0.488, loss=0.904]
# 1/50 * Epoch (valid):  67% 6/9 [00:12<00:06,  2.11s/it, _timers/_fps=408.909, dice=0.488, loss=0.904]
# 1/50 * Epoch (valid):  67% 6/9 [00:13<00:06,  2.11s/it, _timers/_fps=406.525, dice=0.502, loss=0.916]
# 1/50 * Epoch (valid):  78% 7/9 [00:13<00:03,  1.64s/it, _timers/_fps=406.525, dice=0.502, loss=0.916]
# 1/50 * Epoch (valid):  78% 7/9 [00:13<00:03,  1.64s/it, _timers/_fps=419.178, dice=0.516, loss=0.868]
# 1/50 * Epoch (valid):  89% 8/9 [00:13<00:01,  1.31s/it, _timers/_fps=419.178, dice=0.516, loss=0.868]
# 1/50 * Epoch (valid):  89% 8/9 [00:14<00:01,  1.31s/it, _timers/_fps=521.623, dice=0.462, loss=0.927]
# 1/50 * Epoch (valid): 100% 9/9 [00:14<00:00,  1.58s/it, _timers/_fps=521.623, dice=0.462, loss=0.927]
# [2019-10-30 18:53:31,913]
# 1/50 * Epoch 1 (train): _base/lr=0.0100 | _base/momentum=0.9000 | _timers/_fps=201.6625 | _timers/batch_time=1.6376 | _timers/data_time=1.5952 | _timers/model_time=0.0422 | dice=0.4615 | loss=0.8635
# 1/50 * Epoch 1 (valid): _base/lr=0.0100 | _base/momentum=0.9000 | _timers/_fps=377.3800 | _timers/batch_time=1.1965 | _timers/data_time=1.1804 | _timers/model_time=0.0161 | dice=0.4860 | loss=0.8975
# [2019-10-30 18:53:31,913]
# 1/50 * Epoch 1 (train): _base/lr=0.0100 | _base/momentum=0.9000 | _timers/_fps=201.6625 | _timers/batch_time=1.6376 | _timers/data_time=1.5952 | _timers/model_time=0.0422 | dice=0.4615 | loss=0.8635
# 1/50 * Epoch 1 (valid): _base/lr=0.0100 | _base/momentum=0.9000 | _timers/_fps=377.3800 | _timers/batch_time=1.1965 | _timers/data_time=1.1804 | _timers/model_time=0.0161 | dice=0.4860 | loss=0.8975
#
# 2/50 * Epoch (train):   0% 0/78 [00:00<?, ?it/s]
# 2/50 * Epoch (train):   0% 0/78 [00:24<?, ?it/s, _timers/_fps=2.758, dice=0.495, loss=0.794]
# 2/50 * Epoch (train):   1% 1/78 [00:24<31:35, 24.62s/it, _timers/_fps=2.758, dice=0.495, loss=0.794]
# 2/50 * Epoch (train):   1% 1/78 [00:26<31:35, 24.62s/it, _timers/_fps=174.654, dice=0.461, loss=0.891]
# 2/50 * Epoch (train):   3% 2/78 [00:26<22:30, 17.77s/it, _timers/_fps=174.654, dice=0.461, loss=0.891]
# 2/50 * Epoch (train):   3% 2/78 [00:28<22:30, 17.77s/it, _timers/_fps=279.178, dice=0.466, loss=0.828]
# 2/50 * Epoch (train):   4% 3/78 [00:28<16:10, 12.94s/it, _timers/_fps=279.178, dice=0.466, loss=0.828]
# 2/50 * Epoch (train):   4% 3/78 [00:29<16:10, 12.94s/it, _timers/_fps=182.162, dice=0.496, loss=0.801]
# 2/50 * Epoch (train):   5% 4/78 [00:29<11:49,  9.59s/it, _timers/_fps=182.162, dice=0.496, loss=0.801]
# 2/50 * Epoch (train):   5% 4/78 [00:31<11:49,  9.59s/it, _timers/_fps=285.683, dice=0.489, loss=0.819]
# 2/50 * Epoch (train):   6% 5/78 [00:31<08:47,  7.22s/it, _timers/_fps=285.683, dice=0.489, loss=0.819]
# 2/50 * Epoch (train):   6% 5/78 [00:33<08:47,  7.22s/it, _timers/_fps=265.951, dice=0.492, loss=0.805]
# 2/50 * Epoch (train):   8% 6/78 [00:33<06:40,  5.56s/it, _timers/_fps=265.951, dice=0.492, loss=0.805]
# 2/50 * Epoch (train):   8% 6/78 [00:35<06:40,  5.56s/it, _timers/_fps=168.450, dice=0.440, loss=0.906]
# 2/50 * Epoch (train):   9% 7/78 [00:35<05:15,  4.44s/it, _timers/_fps=168.450, dice=0.440, loss=0.906]
# 2/50 * Epoch (train):   9% 7/78 [00:36<05:15,  4.44s/it, _timers/_fps=321.159, dice=0.466, loss=0.866]
# 2/50 * Epoch (train):  10% 8/78 [00:36<04:12,  3.60s/it, _timers/_fps=321.159, dice=0.466, loss=0.866]
# 2/50 * Epoch (train):  10% 8/78 [00:48<04:12,  3.60s/it, _timers/_fps=6.075, dice=0.483, loss=0.849]
# 2/50 * Epoch (train):  12% 9/78 [00:48<07:02,  6.12s/it, _timers/_fps=6.075, dice=0.483, loss=0.849]
# 2/50 * Epoch (train):  12% 9/78 [00:50<07:02,  6.12s/it, _timers/_fps=215.822, dice=0.449, loss=0.876]
# 2/50 * Epoch (train):  13% 10/78 [00:50<05:26,  4.81s/it, _timers/_fps=215.822, dice=0.449, loss=0.876]
# 2/50 * Epoch (train):  13% 10/78 [00:52<05:26,  4.81s/it, _timers/_fps=291.778, dice=0.473, loss=0.864]
# 2/50 * Epoch (train):  14% 11/78 [00:52<04:18,  3.86s/it, _timers/_fps=291.778, dice=0.473, loss=0.864]
# 2/50 * Epoch (train):  14% 11/78 [00:53<04:18,  3.86s/it, _timers/_fps=278.501, dice=0.495, loss=0.807]
# 2/50 * Epoch (train):  15% 12/78 [00:53<03:31,  3.20s/it, _timers/_fps=278.501, dice=0.495, loss=0.807]
# 2/50 * Epoch (train):  15% 12/78 [00:55<03:31,  3.20s/it, _timers/_fps=301.399, dice=0.498, loss=0.834]
# 2/50 * Epoch (train):  17% 13/78 [00:55<02:58,  2.75s/it, _timers/_fps=301.399, dice=0.498, loss=0.834]
# 2/50 * Epoch (train):  17% 13/78 [00:57<02:58,  2.75s/it, _timers/_fps=236.806, dice=0.508, loss=0.788]
# 2/50 * Epoch (train):  18% 14/78 [00:57<02:36,  2.44s/it, _timers/_fps=236.806, dice=0.508, loss=0.788]
# 2/50 * Epoch (train):  18% 14/78 [00:58<02:36,  2.44s/it, _timers/_fps=295.996, dice=0.487, loss=0.843]
# 2/50 * Epoch (train):  19% 15/78 [00:58<02:18,  2.20s/it, _timers/_fps=295.996, dice=0.487, loss=0.843]
# 2/50 * Epoch (train):  19% 15/78 [01:00<02:18,  2.20s/it, _timers/_fps=277.766, dice=0.498, loss=0.830]
# 2/50 * Epoch (train):  21% 16/78 [01:00<02:06,  2.04s/it, _timers/_fps=277.766, dice=0.498, loss=0.830]
# 2/50 * Epoch (train):  21% 16/78 [01:14<02:06,  2.04s/it, _timers/_fps=5.238, dice=0.529, loss=0.732]
# 2/50 * Epoch (train):  22% 17/78 [01:14<05:37,  5.53s/it, _timers/_fps=5.238, dice=0.529, loss=0.732]
# 2/50 * Epoch (train):  22% 17/78 [01:15<05:37,  5.53s/it, _timers/_fps=149.779, dice=0.524, loss=0.792]
# 2/50 * Epoch (train):  23% 18/78 [01:16<04:25,  4.42s/it, _timers/_fps=149.779, dice=0.524, loss=0.792]
# 2/50 * Epoch (train):  23% 18/78 [01:17<04:25,  4.42s/it, _timers/_fps=143.203, dice=0.482, loss=0.859]
# 2/50 * Epoch (train):  24% 19/78 [01:17<03:35,  3.65s/it, _timers/_fps=143.203, dice=0.482, loss=0.859]
# 2/50 * Epoch (train):  24% 19/78 [01:19<03:35,  3.65s/it, _timers/_fps=279.080, dice=0.504, loss=0.810]
# 2/50 * Epoch (train):  26% 20/78 [01:19<02:57,  3.06s/it, _timers/_fps=279.080, dice=0.504, loss=0.810]
# 2/50 * Epoch (train):  26% 20/78 [01:21<02:57,  3.06s/it, _timers/_fps=274.508, dice=0.472, loss=0.892]
# 2/50 * Epoch (train):  27% 21/78 [01:21<02:30,  2.64s/it, _timers/_fps=274.508, dice=0.472, loss=0.892]
# 2/50 * Epoch (train):  27% 21/78 [01:22<02:30,  2.64s/it, _timers/_fps=215.619, dice=0.487, loss=0.839]
# 2/50 * Epoch (train):  28% 22/78 [01:22<02:12,  2.37s/it, _timers/_fps=215.619, dice=0.487, loss=0.839]
# 2/50 * Epoch (train):  28% 22/78 [01:24<02:12,  2.37s/it, _timers/_fps=144.672, dice=0.475, loss=0.888]
# 2/50 * Epoch (train):  29% 23/78 [01:24<02:02,  2.23s/it, _timers/_fps=144.672, dice=0.475, loss=0.888]
# 2/50 * Epoch (train):  29% 23/78 [01:26<02:02,  2.23s/it, _timers/_fps=268.922, dice=0.538, loss=0.757]
# 2/50 * Epoch (train):  31% 24/78 [01:26<01:51,  2.07s/it, _timers/_fps=268.922, dice=0.538, loss=0.757]
# 2/50 * Epoch (train):  31% 24/78 [01:38<01:51,  2.07s/it, _timers/_fps=5.874, dice=0.506, loss=0.816]
# 2/50 * Epoch (train):  32% 25/78 [01:38<04:32,  5.14s/it, _timers/_fps=5.874, dice=0.506, loss=0.816]
# 2/50 * Epoch (train):  32% 25/78 [01:40<04:32,  5.14s/it, _timers/_fps=164.536, dice=0.432, loss=0.916]
# 2/50 * Epoch (train):  33% 26/78 [01:40<03:35,  4.14s/it, _timers/_fps=164.536, dice=0.432, loss=0.916]
# 2/50 * Epoch (train):  33% 26/78 [01:42<03:35,  4.14s/it, _timers/_fps=300.081, dice=0.473, loss=0.877]
# 2/50 * Epoch (train):  35% 27/78 [01:42<02:53,  3.40s/it, _timers/_fps=300.081, dice=0.473, loss=0.877]
# 2/50 * Epoch (train):  35% 27/78 [01:43<02:53,  3.40s/it, _timers/_fps=272.500, dice=0.487, loss=0.794]
# 2/50 * Epoch (train):  36% 28/78 [01:43<02:24,  2.88s/it, _timers/_fps=272.500, dice=0.487, loss=0.794]
# 2/50 * Epoch (train):  36% 28/78 [01:45<02:24,  2.88s/it, _timers/_fps=219.310, dice=0.515, loss=0.757]
# 2/50 * Epoch (train):  37% 29/78 [01:45<02:04,  2.54s/it, _timers/_fps=219.310, dice=0.515, loss=0.757]
# 2/50 * Epoch (train):  37% 29/78 [01:47<02:04,  2.54s/it, _timers/_fps=292.341, dice=0.493, loss=0.795]
# 2/50 * Epoch (train):  38% 30/78 [01:47<01:49,  2.27s/it, _timers/_fps=292.341, dice=0.493, loss=0.795]
# 2/50 * Epoch (train):  38% 30/78 [01:49<01:49,  2.27s/it, _timers/_fps=232.161, dice=0.463, loss=0.881]
# 2/50 * Epoch (train):  40% 31/78 [01:49<01:39,  2.11s/it, _timers/_fps=232.161, dice=0.463, loss=0.881]
# 2/50 * Epoch (train):  40% 31/78 [01:50<01:39,  2.11s/it, _timers/_fps=281.936, dice=0.464, loss=0.851]
# 2/50 * Epoch (train):  41% 32/78 [01:50<01:30,  1.97s/it, _timers/_fps=281.936, dice=0.464, loss=0.851]
# 2/50 * Epoch (train):  41% 32/78 [02:03<01:30,  1.97s/it, _timers/_fps=5.439, dice=0.519, loss=0.773]
# 2/50 * Epoch (train):  42% 33/78 [02:03<04:00,  5.34s/it, _timers/_fps=5.439, dice=0.519, loss=0.773]
# 2/50 * Epoch (train):  42% 33/78 [02:05<04:00,  5.34s/it, _timers/_fps=168.180, dice=0.494, loss=0.795]
# 2/50 * Epoch (train):  44% 34/78 [02:05<03:08,  4.28s/it, _timers/_fps=168.180, dice=0.494, loss=0.795]
# 2/50 * Epoch (train):  44% 34/78 [02:07<03:08,  4.28s/it, _timers/_fps=294.809, dice=0.461, loss=0.882]
# 2/50 * Epoch (train):  45% 35/78 [02:07<02:30,  3.50s/it, _timers/_fps=294.809, dice=0.461, loss=0.882]
# 2/50 * Epoch (train):  45% 35/78 [02:09<02:30,  3.50s/it, _timers/_fps=134.879, dice=0.451, loss=0.897]
# 2/50 * Epoch (train):  46% 36/78 [02:09<02:06,  3.02s/it, _timers/_fps=134.879, dice=0.451, loss=0.897]
# 2/50 * Epoch (train):  46% 36/78 [02:11<02:06,  3.02s/it, _timers/_fps=167.379, dice=0.484, loss=0.861]
# 2/50 * Epoch (train):  47% 37/78 [02:11<01:49,  2.66s/it, _timers/_fps=167.379, dice=0.484, loss=0.861]
# 2/50 * Epoch (train):  47% 37/78 [02:12<01:49,  2.66s/it, _timers/_fps=283.967, dice=0.487, loss=0.830]
# 2/50 * Epoch (train):  49% 38/78 [02:12<01:34,  2.36s/it, _timers/_fps=283.967, dice=0.487, loss=0.830]
# 2/50 * Epoch (train):  49% 38/78 [02:14<01:34,  2.36s/it, _timers/_fps=224.721, dice=0.490, loss=0.818]
# 2/50 * Epoch (train):  50% 39/78 [02:14<01:24,  2.17s/it, _timers/_fps=224.721, dice=0.490, loss=0.818]
# 2/50 * Epoch (train):  50% 39/78 [02:16<01:24,  2.17s/it, _timers/_fps=286.430, dice=0.469, loss=0.873]
# 2/50 * Epoch (train):  51% 40/78 [02:16<01:17,  2.04s/it, _timers/_fps=286.430, dice=0.469, loss=0.873]
# 2/50 * Epoch (train):  51% 40/78 [02:28<01:17,  2.04s/it, _timers/_fps=5.696, dice=0.467, loss=0.866]
# 2/50 * Epoch (train):  53% 41/78 [02:28<03:13,  5.23s/it, _timers/_fps=5.696, dice=0.467, loss=0.866]
# 2/50 * Epoch (train):  53% 41/78 [02:30<03:13,  5.23s/it, _timers/_fps=296.174, dice=0.472, loss=0.838]
# 2/50 * Epoch (train):  54% 42/78 [02:30<02:29,  4.16s/it, _timers/_fps=296.174, dice=0.472, loss=0.838]
# 2/50 * Epoch (train):  54% 42/78 [02:32<02:29,  4.16s/it, _timers/_fps=253.110, dice=0.498, loss=0.832]
# 2/50 * Epoch (train):  55% 43/78 [02:32<01:59,  3.42s/it, _timers/_fps=253.110, dice=0.498, loss=0.832]
# 2/50 * Epoch (train):  55% 43/78 [02:33<01:59,  3.42s/it, _timers/_fps=277.763, dice=0.475, loss=0.835]
# 2/50 * Epoch (train):  56% 44/78 [02:34<01:38,  2.90s/it, _timers/_fps=277.763, dice=0.475, loss=0.835]
# 2/50 * Epoch (train):  56% 44/78 [02:35<01:38,  2.90s/it, _timers/_fps=270.757, dice=0.479, loss=0.833]
# 2/50 * Epoch (train):  58% 45/78 [02:35<01:23,  2.54s/it, _timers/_fps=270.757, dice=0.479, loss=0.833]
# 2/50 * Epoch (train):  58% 45/78 [02:37<01:23,  2.54s/it, _timers/_fps=259.880, dice=0.481, loss=0.855]
# 2/50 * Epoch (train):  59% 46/78 [02:37<01:13,  2.29s/it, _timers/_fps=259.880, dice=0.481, loss=0.855]
# 2/50 * Epoch (train):  59% 46/78 [02:39<01:13,  2.29s/it, _timers/_fps=271.474, dice=0.506, loss=0.790]
# 2/50 * Epoch (train):  60% 47/78 [02:39<01:05,  2.10s/it, _timers/_fps=271.474, dice=0.506, loss=0.790]
# 2/50 * Epoch (train):  60% 47/78 [02:40<01:05,  2.10s/it, _timers/_fps=290.822, dice=0.485, loss=0.843]
# 2/50 * Epoch (train):  62% 48/78 [02:40<00:59,  1.97s/it, _timers/_fps=290.822, dice=0.485, loss=0.843]
# 2/50 * Epoch (train):  62% 48/78 [02:53<00:59,  1.97s/it, _timers/_fps=5.521, dice=0.485, loss=0.804]
# ...
# 22/50 * Epoch (train):  21% 16/78 [00:58<02:05,  2.02s/it, _timers/_fps=273.217, dice=0.541, loss=0.774]
# 22/50 * Epoch (train):  21% 16/78 [01:10<02:05,  2.02s/it, _timers/_fps=5.874, dice=0.581, loss=0.679]
# 22/50 * Epoch (train):  22% 17/78 [01:10<05:12,  5.12s/it, _timers/_fps=5.874, dice=0.581, loss=0.679]
# 22/50 * Epoch (train):  22% 17/78 [01:12<05:12,  5.12s/it, _timers/_fps=279.412, dice=0.553, loss=0.728]
# 22/50 * Epoch (train):  23% 18/78 [01:12<04:05,  4.09s/it, _timers/_fps=279.412, dice=0.553, loss=0.728]
# 22/50 * Epoch (train):  23% 18/78 [01:13<04:05,  4.09s/it, _timers/_fps=134.956, dice=0.548, loss=0.732]
# 22/50 * Epoch (train):  24% 19/78 [01:13<03:22,  3.43s/it, _timers/_fps=134.956, dice=0.548, loss=0.732]
# 22/50 * Epoch (train):  24% 19/78 [01:15<03:22,  3.43s/it, _timers/_fps=161.826, dice=0.565, loss=0.744]
# 22/50 * Epoch (train):  26% 20/78 [01:15<02:50,  2.94s/it, _timers/_fps=161.826, dice=0.565, loss=0.744]
# 22/50 * Epoch (train):  26% 20/78 [01:17<02:50,  2.94s/it, _timers/_fps=284.567, dice=0.608, loss=0.647]
# 22/50 * Epoch (train):  27% 21/78 [01:17<02:25,  2.56s/it, _timers/_fps=284.567, dice=0.608, loss=0.647]
# 22/50 * Epoch (train):  27% 21/78 [01:19<02:25,  2.56s/it, _timers/_fps=158.113, dice=0.579, loss=0.714]
# 22/50 * Epoch (train):  28% 22/78 [01:19<02:10,  2.33s/it, _timers/_fps=158.113, dice=0.579, loss=0.714]
# 22/50 * Epoch (train):  28% 22/78 [01:21<02:10,  2.33s/it, _timers/_fps=160.447, dice=0.542, loss=0.754]
# 22/50 * Epoch (train):  29% 23/78 [01:21<01:59,  2.17s/it, _timers/_fps=160.447, dice=0.542, loss=0.754]
# 22/50 * Epoch (train):  29% 23/78 [01:22<01:59,  2.17s/it, _timers/_fps=278.156, dice=0.573, loss=0.702]
# 22/50 * Epoch (train):  31% 24/78 [01:22<01:49,  2.03s/it, _timers/_fps=278.156, dice=0.573, loss=0.702]
# 22/50 * Epoch (train):  31% 24/78 [01:34<01:49,  2.03s/it, _timers/_fps=6.395, dice=0.586, loss=0.686]
# 22/50 * Epoch (train):  32% 25/78 [01:34<04:17,  4.85s/it, _timers/_fps=6.395, dice=0.586, loss=0.686]
# 22/50 * Epoch (train):  32% 25/78 [01:35<04:17,  4.85s/it, _timers/_fps=292.939, dice=0.573, loss=0.682]
# 22/50 * Epoch (train):  33% 26/78 [01:35<03:22,  3.89s/it, _timers/_fps=292.939, dice=0.573, loss=0.682]
# 22/50 * Epoch (train):  33% 26/78 [01:37<03:22,  3.89s/it, _timers/_fps=285.453, dice=0.617, loss=0.603]
# 22/50 * Epoch (train):  35% 27/78 [01:37<02:44,  3.22s/it, _timers/_fps=285.453, dice=0.617, loss=0.603]
# 22/50 * Epoch (train):  35% 27/78 [01:39<02:44,  3.22s/it, _timers/_fps=286.049, dice=0.566, loss=0.690]
# 22/50 * Epoch (train):  36% 28/78 [01:39<02:17,  2.76s/it, _timers/_fps=286.049, dice=0.566, loss=0.690]
# 22/50 * Epoch (train):  36% 28/78 [01:40<02:17,  2.76s/it, _timers/_fps=237.858, dice=0.577, loss=0.712]
# 22/50 * Epoch (train):  37% 29/78 [01:40<01:58,  2.43s/it, _timers/_fps=237.858, dice=0.577, loss=0.712]
# 22/50 * Epoch (train):  37% 29/78 [01:42<01:58,  2.43s/it, _timers/_fps=276.697, dice=0.581, loss=0.665]
# 22/50 * Epoch (train):  38% 30/78 [01:42<01:45,  2.20s/it, _timers/_fps=276.697, dice=0.581, loss=0.665]
# 22/50 * Epoch (train):  38% 30/78 [01:44<01:45,  2.20s/it, _timers/_fps=245.307, dice=0.593, loss=0.642]
# 22/50 * Epoch (train):  40% 31/78 [01:44<01:36,  2.05s/it, _timers/_fps=245.307, dice=0.593, loss=0.642]
# 22/50 * Epoch (train):  40% 31/78 [01:45<01:36,  2.05s/it, _timers/_fps=284.559, dice=0.539, loss=0.741]
# 22/50 * Epoch (train):  41% 32/78 [01:45<01:29,  1.95s/it, _timers/_fps=284.559, dice=0.539, loss=0.741]
# 22/50 * Epoch (train):  41% 32/78 [01:58<01:29,  1.95s/it, _timers/_fps=5.977, dice=0.528, loss=0.760]
# 22/50 * Epoch (train):  42% 33/78 [01:58<03:45,  5.02s/it, _timers/_fps=5.977, dice=0.528, loss=0.760]
# 22/50 * Epoch (train):  42% 33/78 [01:59<03:45,  5.02s/it, _timers/_fps=164.189, dice=0.573, loss=0.691]
# 22/50 * Epoch (train):  44% 34/78 [01:59<02:58,  4.07s/it, _timers/_fps=164.189, dice=0.573, loss=0.691]
# 22/50 * Epoch (train):  44% 34/78 [02:01<02:58,  4.07s/it, _timers/_fps=294.280, dice=0.531, loss=0.768]
# 22/50 * Epoch (train):  45% 35/78 [02:01<02:23,  3.35s/it, _timers/_fps=294.280, dice=0.531, loss=0.768]
# 22/50 * Epoch (train):  45% 35/78 [02:03<02:23,  3.35s/it, _timers/_fps=283.747, dice=0.590, loss=0.659]
# 22/50 * Epoch (train):  46% 36/78 [02:03<01:59,  2.84s/it, _timers/_fps=283.747, dice=0.590, loss=0.659]
# 22/50 * Epoch (train):  46% 36/78 [02:04<01:59,  2.84s/it, _timers/_fps=243.346, dice=0.584, loss=0.669]
# 22/50 * Epoch (train):  47% 37/78 [02:04<01:42,  2.49s/it, _timers/_fps=243.346, dice=0.584, loss=0.669]
# 22/50 * Epoch (train):  47% 37/78 [02:06<01:42,  2.49s/it, _timers/_fps=289.159, dice=0.570, loss=0.691]
# 22/50 * Epoch (train):  49% 38/78 [02:06<01:29,  2.25s/it, _timers/_fps=289.159, dice=0.570, loss=0.691]
# 22/50 * Epoch (train):  49% 38/78 [02:08<01:29,  2.25s/it, _timers/_fps=170.227, dice=0.597, loss=0.650]
# 22/50 * Epoch (train):  50% 39/78 [02:08<01:22,  2.11s/it, _timers/_fps=170.227, dice=0.597, loss=0.650]
# 22/50 * Epoch (train):  50% 39/78 [02:10<01:22,  2.11s/it, _timers/_fps=284.881, dice=0.566, loss=0.698]
# 22/50 * Epoch (train):  51% 40/78 [02:10<01:15,  1.99s/it, _timers/_fps=284.881, dice=0.566, loss=0.698]
# 22/50 * Epoch (train):  51% 40/78 [02:21<01:15,  1.99s/it, _timers/_fps=6.622, dice=0.574, loss=0.692]
# 22/50 * Epoch (train):  53% 41/78 [02:21<02:55,  4.74s/it, _timers/_fps=6.622, dice=0.574, loss=0.692]
# 22/50 * Epoch (train):  53% 41/78 [02:23<02:55,  4.74s/it, _timers/_fps=53.110, dice=0.540, loss=0.760]
# 22/50 * Epoch (train):  54% 42/78 [02:23<02:27,  4.11s/it, _timers/_fps=53.110, dice=0.540, loss=0.760]
# 22/50 * Epoch (train):  54% 42/78 [02:25<02:27,  4.11s/it, _timers/_fps=208.309, dice=0.599, loss=0.642]
# 22/50 * Epoch (train):  55% 43/78 [02:25<01:59,  3.40s/it, _timers/_fps=208.309, dice=0.599, loss=0.642]
# 22/50 * Epoch (train):  55% 43/78 [02:27<01:59,  3.40s/it, _timers/_fps=282.137, dice=0.579, loss=0.668]
# 22/50 * Epoch (train):  56% 44/78 [02:27<01:38,  2.89s/it, _timers/_fps=282.137, dice=0.579, loss=0.668]
# 22/50 * Epoch (train):  56% 44/78 [02:29<01:38,  2.89s/it, _timers/_fps=164.327, dice=0.538, loss=0.747]
# 22/50 * Epoch (train):  58% 45/78 [02:29<01:24,  2.57s/it, _timers/_fps=164.327, dice=0.538, loss=0.747]
# 22/50 * Epoch (train):  58% 45/78 [02:30<01:24,  2.57s/it, _timers/_fps=282.935, dice=0.543, loss=0.764]
# 22/50 * Epoch (train):  59% 46/78 [02:30<01:13,  2.30s/it, _timers/_fps=282.935, dice=0.543, loss=0.764]
# 22/50 * Epoch (train):  59% 46/78 [02:32<01:13,  2.30s/it, _timers/_fps=286.401, dice=0.545, loss=0.752]
# 22/50 * Epoch (train):  60% 47/78 [02:32<01:05,  2.11s/it, _timers/_fps=286.401, dice=0.545, loss=0.752]
# 22/50 * Epoch (train):  60% 47/78 [02:34<01:05,  2.11s/it, _timers/_fps=280.549, dice=0.593, loss=0.665]
# 22/50 * Epoch (train):  62% 48/78 [02:34<00:59,  1.99s/it, _timers/_fps=280.549, dice=0.593, loss=0.665]
# 22/50 * Epoch (train):  62% 48/78 [02:42<00:59,  1.99s/it, _timers/_fps=10.028, dice=0.603, loss=0.657]
# 22/50 * Epoch (train):  63% 49/78 [02:42<01:48,  3.74s/it, _timers/_fps=10.028, dice=0.603, loss=0.657]
# 22/50 * Epoch (train):  63% 49/78 [02:47<01:48,  3.74s/it, _timers/_fps=14.779, dice=0.599, loss=0.665]
# 22/50 * Epoch (train):  64% 50/78 [02:47<02:01,  4.35s/it, _timers/_fps=14.779, dice=0.599, loss=0.665]
# 22/50 * Epoch (train):  64% 50/78 [02:49<02:01,  4.35s/it, _timers/_fps=145.865, dice=0.539, loss=0.743]
# 22/50 * Epoch (train):  65% 51/78 [02:49<01:37,  3.61s/it, _timers/_fps=145.865, dice=0.539, loss=0.743]
# 22/50 * Epoch (train):  65% 51/78 [02:51<01:37,  3.61s/it, _timers/_fps=180.851, dice=0.596, loss=0.665]
# 22/50 * Epoch (train):  67% 52/78 [02:51<01:19,  3.07s/it, _timers/_fps=180.851, dice=0.596, loss=0.665]
# 22/50 * Epoch (train):  67% 52/78 [02:53<01:19,  3.07s/it, _timers/_fps=216.942, dice=0.574, loss=0.667]
# 22/50 * Epoch (train):  68% 53/78 [02:53<01:07,  2.68s/it, _timers/_fps=216.942, dice=0.574, loss=0.667]
# 22/50 * Epoch (train):  68% 53/78 [02:55<01:07,  2.68s/it, _timers/_fps=136.441, dice=0.590, loss=0.670]
# 22/50 * Epoch (train):  69% 54/78 [02:55<00:58,  2.45s/it, _timers/_fps=136.441, dice=0.590, loss=0.670]
# 22/50 * Epoch (train):  69% 54/78 [02:56<00:58,  2.45s/it, _timers/_fps=281.517, dice=0.586, loss=0.663]
# 22/50 * Epoch (train):  71% 55/78 [02:56<00:50,  2.21s/it, _timers/_fps=281.517, dice=0.586, loss=0.663]
# 22/50 * Epoch (train):  71% 55/78 [02:58<00:50,  2.21s/it, _timers/_fps=246.256, dice=0.583, loss=0.698]
# 22/50 * Epoch (train):  72% 56/78 [02:58<00:45,  2.06s/it, _timers/_fps=246.256, dice=0.583, loss=0.698]
# 22/50 * Epoch (train):  72% 56/78 [03:04<00:45,  2.06s/it, _timers/_fps=13.764, dice=0.581, loss=0.675]
# 22/50 * Epoch (train):  73% 57/78 [03:04<01:08,  3.27s/it, _timers/_fps=13.764, dice=0.581, loss=0.675]
# 22/50 * Epoch (train):  73% 57/78 [03:10<01:08,  3.27s/it, _timers/_fps=13.295, dice=0.613, loss=0.645]
# 22/50 * Epoch (train):  74% 58/78 [03:10<01:23,  4.17s/it, _timers/_fps=13.295, dice=0.613, loss=0.645]
# 22/50 * Epoch (train):  74% 58/78 [03:12<01:23,  4.17s/it, _timers/_fps=276.445, dice=0.562, loss=0.718]
# 22/50 * Epoch (train):  76% 59/78 [03:12<01:05,  3.42s/it, _timers/_fps=276.445, dice=0.562, loss=0.718]
# 22/50 * Epoch (train):  76% 59/78 [03:14<01:05,  3.42s/it, _timers/_fps=286.838, dice=0.576, loss=0.700]
# 22/50 * Epoch (train):  77% 60/78 [03:14<00:52,  2.90s/it, _timers/_fps=286.838, dice=0.576, loss=0.700]
# 22/50 * Epoch (train):  77% 60/78 [03:16<00:52,  2.90s/it, _timers/_fps=87.071, dice=0.556, loss=0.748]
# 22/50 * Epoch (train):  78% 61/78 [03:16<00:45,  2.69s/it, _timers/_fps=87.071, dice=0.556, loss=0.748]
# 22/50 * Epoch (train):  78% 61/78 [03:18<00:45,  2.69s/it, _timers/_fps=241.740, dice=0.569, loss=0.736]
# 22/50 * Epoch (train):  79% 62/78 [03:18<00:38,  2.40s/it, _timers/_fps=241.740, dice=0.569, loss=0.736]
# 22/50 * Epoch (train):  79% 62/78 [03:20<00:38,  2.40s/it, _timers/_fps=179.977, dice=0.597, loss=0.682]
# 22/50 * Epoch (train):  81% 63/78 [03:20<00:33,  2.23s/it, _timers/_fps=179.977, dice=0.597, loss=0.682]
# 22/50 * Epoch (train):  81% 63/78 [03:21<00:33,  2.23s/it, _timers/_fps=167.707, dice=0.579, loss=0.690]
# 22/50 * Epoch (train):  82% 64/78 [03:21<00:29,  2.12s/it, _timers/_fps=167.707, dice=0.579, loss=0.690]
# 22/50 * Epoch (train):  82% 64/78 [03:27<00:29,  2.12s/it, _timers/_fps=14.081, dice=0.567, loss=0.717]
# 22/50 * Epoch (train):  83% 65/78 [03:27<00:42,  3.29s/it, _timers/_fps=14.081, dice=0.567, loss=0.717]
# 22/50 * Epoch (train):  83% 65/78 [03:31<00:42,  3.29s/it, _timers/_fps=24.867, dice=0.542, loss=0.755]
# 22/50 * Epoch (train):  85% 66/78 [03:31<00:42,  3.50s/it, _timers/_fps=24.867, dice=0.542, loss=0.755]
# 22/50 * Epoch (train):  85% 66/78 [03:33<00:42,  3.50s/it, _timers/_fps=273.558, dice=0.552, loss=0.722]
# 22/50 * Epoch (train):  86% 67/78 [03:33<00:32,  2.95s/it, _timers/_fps=273.558, dice=0.552, loss=0.722]
# 22/50 * Epoch (train):  86% 67/78 [03:35<00:32,  2.95s/it, _timers/_fps=272.814, dice=0.575, loss=0.704]
# 22/50 * Epoch (train):  87% 68/78 [03:35<00:25,  2.57s/it, _timers/_fps=272.814, dice=0.575, loss=0.704]
# 22/50 * Epoch (train):  87% 68/78 [03:38<00:25,  2.57s/it, _timers/_fps=40.403, dice=0.518, loss=0.766]
# 22/50 * Epoch (train):  88% 69/78 [03:38<00:24,  2.71s/it, _timers/_fps=40.403, dice=0.518, loss=0.766]
# 22/50 * Epoch (train):  88% 69/78 [03:39<00:24,  2.71s/it, _timers/_fps=270.472, dice=0.588, loss=0.671]
# 22/50 * Epoch (train):  90% 70/78 [03:39<00:19,  2.40s/it, _timers/_fps=270.472, dice=0.588, loss=0.671]
# 22/50 * Epoch (train):  90% 70/78 [03:41<00:19,  2.40s/it, _timers/_fps=291.122, dice=0.536, loss=0.752]
# 22/50 * Epoch (train):  91% 71/78 [03:41<00:15,  2.17s/it, _timers/_fps=291.122, dice=0.536, loss=0.752]
# 22/50 * Epoch (train):  91% 71/78 [03:43<00:15,  2.17s/it, _timers/_fps=264.141, dice=0.570, loss=0.716]
# 22/50 * Epoch (train):  92% 72/78 [03:43<00:12,  2.02s/it, _timers/_fps=264.141, dice=0.570, loss=0.716]
# 22/50 * Epoch (train):  92% 72/78 [03:48<00:12,  2.02s/it, _timers/_fps=17.291, dice=0.536, loss=0.747]
# 22/50 * Epoch (train):  94% 73/78 [03:48<00:14,  2.95s/it, _timers/_fps=17.291, dice=0.536, loss=0.747]
# 22/50 * Epoch (train):  94% 73/78 [03:50<00:14,  2.95s/it, _timers/_fps=141.525, dice=0.574, loss=0.686]
# 22/50 * Epoch (train):  95% 74/78 [03:50<00:10,  2.63s/it, _timers/_fps=141.525, dice=0.574, loss=0.686]
# 22/50 * Epoch (train):  95% 74/78 [03:51<00:10,  2.63s/it, _timers/_fps=370.756, dice=0.584, loss=0.644]
# 22/50 * Epoch (train):  96% 75/78 [03:51<00:06,  2.32s/it, _timers/_fps=370.756, dice=0.584, loss=0.644]
# 22/50 * Epoch (train):  96% 75/78 [03:53<00:06,  2.32s/it, _timers/_fps=376.504, dice=0.520, loss=0.757]
# 22/50 * Epoch (train):  97% 76/78 [03:53<00:04,  2.11s/it, _timers/_fps=376.504, dice=0.520, loss=0.757]
# 22/50 * Epoch (train):  97% 76/78 [03:55<00:04,  2.11s/it, _timers/_fps=72.985, dice=0.538, loss=0.741]
# 22/50 * Epoch (train):  99% 77/78 [03:55<00:02,  2.17s/it, _timers/_fps=72.985, dice=0.538, loss=0.741]
# 22/50 * Epoch (train):  99% 77/78 [03:57<00:02,  2.17s/it, _timers/_fps=375.816, dice=0.556, loss=0.711]
# 22/50 * Epoch (train): 100% 78/78 [03:57<00:00,  3.05s/it, _timers/_fps=375.816, dice=0.556, loss=0.711]
#
# 22/50 * Epoch (valid):   0% 0/9 [00:00<?, ?it/s]
# 22/50 * Epoch (valid):   0% 0/9 [00:09<?, ?it/s, _timers/_fps=6.828, dice=0.552, loss=0.754]
# 22/50 * Epoch (valid):  11% 1/9 [00:09<01:17,  9.75s/it, _timers/_fps=6.828, dice=0.552, loss=0.754]
# 22/50 * Epoch (valid):  11% 1/9 [00:10<01:17,  9.75s/it, _timers/_fps=407.501, dice=0.510, loss=0.816]
# 22/50 * Epoch (valid):  22% 2/9 [00:10<00:48,  6.98s/it, _timers/_fps=407.501, dice=0.510, loss=0.816]
# 22/50 * Epoch (valid):  22% 2/9 [00:10<00:48,  6.98s/it, _timers/_fps=399.312, dice=0.568, loss=0.717]
# 22/50 * Epoch (valid):  33% 3/9 [00:10<00:30,  5.05s/it, _timers/_fps=399.312, dice=0.568, loss=0.717]
# 22/50 * Epoch (valid):  33% 3/9 [00:11<00:30,  5.05s/it, _timers/_fps=397.113, dice=0.536, loss=0.783]
# 22/50 * Epoch (valid):  44% 4/9 [00:11<00:18,  3.70s/it, _timers/_fps=397.113, dice=0.536, loss=0.783]
# 22/50 * Epoch (valid):  44% 4/9 [00:11<00:18,  3.70s/it, _timers/_fps=406.050, dice=0.565, loss=0.714]
# 22/50 * Epoch (valid):  56% 5/9 [00:11<00:10,  2.75s/it, _timers/_fps=406.050, dice=0.565, loss=0.714]
# 22/50 * Epoch (valid):  56% 5/9 [00:12<00:10,  2.75s/it, _timers/_fps=400.171, dice=0.579, loss=0.713]
# 22/50 * Epoch (valid):  67% 6/9 [00:12<00:06,  2.09s/it, _timers/_fps=400.171, dice=0.579, loss=0.713]
# 22/50 * Epoch (valid):  67% 6/9 [00:12<00:06,  2.09s/it, _timers/_fps=405.099, dice=0.564, loss=0.774]
# 22/50 * Epoch (valid):  78% 7/9 [00:12<00:03,  1.62s/it, _timers/_fps=405.099, dice=0.564, loss=0.774]
# 22/50 * Epoch (valid):  78% 7/9 [00:13<00:03,  1.62s/it, _timers/_fps=420.795, dice=0.573, loss=0.753]
# 22/50 * Epoch (valid):  89% 8/9 [00:13<00:01,  1.29s/it, _timers/_fps=420.795, dice=0.573, loss=0.753]
# 22/50 * Epoch (valid):  89% 8/9 [00:13<00:01,  1.29s/it, _timers/_fps=524.371, dice=0.542, loss=0.769]
# 22/50 * Epoch (valid): 100% 9/9 [00:14<00:00,  1.56s/it, _timers/_fps=524.371, dice=0.542, loss=0.769]
# Early stop at 22 epoch
# [2019-10-30 20:23:56,848]
# 22/50 * Epoch 22 (train): _base/lr=0.0013 | _base/momentum=0.9000 | _timers/_fps=195.8903 | _timers/batch_time=1.6017 | _timers/data_time=1.5617 | _timers/model_time=0.0397 | dice=0.5690 | loss=0.7014
# 22/50 * Epoch 22 (valid): _base/lr=0.0013 | _base/momentum=0.9000 | _timers/_fps=374.1379 | _timers/batch_time=1.1779 | _timers/data_time=1.1619 | _timers/model_time=0.0159 | dice=0.5542 | loss=0.7548
# [2019-10-30 20:23:56,848]
# 22/50 * Epoch 22 (train): _base/lr=0.0013 | _base/momentum=0.9000 | _timers/_fps=195.8903 | _timers/batch_time=1.6017 | _timers/data_time=1.5617 | _timers/model_time=0.0397 | dice=0.5690 | loss=0.7014
# 22/50 * Epoch 22 (valid): _base/lr=0.0013 | _base/momentum=0.9000 | _timers/_fps=374.1379 | _timers/batch_time=1.1779 | _timers/data_time=1.1619 | _timers/model_time=0.0159 | dice=0.5542 | loss=0.7548
# Top best models:
# logs/segmentation_unet_resnet34/checkpoints//train.17.pth	0.7424

# %%
# utils.plot_metrics(
#     logdir=logdir, 
#     # specify which metrics we want to plot
#     metrics=["loss", "dice", 'lr', '_base/lr']
# )

# %%
import ttach as tta
transforms = tta.Compose(
    [
        tta.HorizontalFlip(),
        tta.VerticalFlip()
        
    ]
)

# %%
encoded_pixels = []
loaders = {"infer": valid_loader}

#tta_model = 

runner.infer(
    model=model,
    loaders=loaders,
    callbacks=[
        CheckpointCallback(
            resume=f"{logdir}/checkpoints/best.pth"),
        InferCallback()
    ],
)

#runner.model = tta.SegmentationTTAWrapper(model, tta.aliases.d4_transform(), merge_mode='mean')
valid_masks = []
probabilities = np.zeros((2220, 350, 525))
for i, (batch, output) in enumerate(tqdm.tqdm(zip(
        valid_dataset, runner.callbacks[0].predictions["logits"]))):
    image, mask = batch
    for m in mask:
        if m.shape != (350, 525):
            m = cv2.resize(m, dsize=(525, 350), interpolation=cv2.INTER_LINEAR)
        valid_masks.append(m)

    for j, probability in enumerate(output):
        if probability.shape != (350, 525):
            probability = cv2.resize(probability, dsize=(525, 350), interpolation=cv2.INTER_LINEAR)
        probabilities[i * 4 + j, :, :] = probability
# Out:
# => loading checkpoint ./logs/segmentation_unet_resnet34/checkpoints/best.pth
# loaded checkpoint ./logs/segmentation_unet_resnet34/checkpoints/best.pth (epoch 17)
# 0it [00:00, ?it/s]
# 2it [00:00, 10.32it/s]
# Top best models:
# 4it [00:00, 10.69it/s]
# 6it [00:00, 10.95it/s]
# 8it [00:00, 11.44it/s]
# 10it [00:00, 11.47it/s]
# 12it [00:01, 11.52it/s]
# 14it [00:01, 11.95it/s]
# 16it [00:01, 12.08it/s]
# 18it [00:01, 11.91it/s]
# 20it [00:01, 11.65it/s]
# 22it [00:01, 12.00it/s]
# 24it [00:02, 11.47it/s]
# 26it [00:02, 11.37it/s]
# 28it [00:02, 11.53it/s]
# 30it [00:02, 11.66it/s]
# 32it [00:02, 11.57it/s]
# 34it [00:02, 11.32it/s]
# 36it [00:03, 11.33it/s]
# 38it [00:03, 11.70it/s]
# 40it [00:03, 11.74it/s]
# 42it [00:03, 11.86it/s]
# 44it [00:03, 11.66it/s]
# 46it [00:03, 12.16it/s]
# 48it [00:04, 12.59it/s]
# 50it [00:04, 12.17it/s]
# 52it [00:04, 11.30it/s]
# 54it [00:04, 10.96it/s]
# 56it [00:04, 10.83it/s]
# 58it [00:04, 11.31it/s]
# 60it [00:05, 10.83it/s]
# 62it [00:05, 11.13it/s]
# 64it [00:05, 11.42it/s]
# 66it [00:05, 11.33it/s]
# 68it [00:05, 11.96it/s]
# 70it [00:06, 11.87it/s]
# 72it [00:06, 11.75it/s]
# 74it [00:06, 11.62it/s]
# 76it [00:06, 11.95it/s]
# 78it [00:06, 11.66it/s]
# 80it [00:06, 11.78it/s]
# 82it [00:07, 11.72it/s]
# 84it [00:07, 11.25it/s]
# 86it [00:07, 11.81it/s]
# 88it [00:07, 11.63it/s]
# 90it [00:07, 11.67it/s]
# 92it [00:07, 12.19it/s]
# 94it [00:08, 12.35it/s]
# 96it [00:08, 12.08it/s]
# 98it [00:08, 12.35it/s]
# 100it [00:08, 12.38it/s]
# 102it [00:08, 12.82it/s]
# 104it [00:08, 12.56it/s]
# 106it [00:09, 12.36it/s]
# 108it [00:09, 12.16it/s]
# 110it [00:09, 12.24it/s]
# 112it [00:09, 11.77it/s]
# 114it [00:09, 11.11it/s]
# 515it [00:50, 10.11it/s]
# 517it [00:50, 10.09it/s]
# 519it [00:50, 10.15it/s]
# 521it [00:50, 10.39it/s]
# 523it [00:51, 10.13it/s]
# 525it [00:51, 10.19it/s]
# 527it [00:51, 10.19it/s]
# 529it [00:51, 10.29it/s]
# 531it [00:51, 10.30it/s]
# 533it [00:52, 10.25it/s]
# 535it [00:52, 10.34it/s]
# 537it [00:52, 10.37it/s]
# 539it [00:52, 10.18it/s]
# 541it [00:52, 10.09it/s]
# 543it [00:53, 10.24it/s]
# 545it [00:53, 10.04it/s]
# 547it [00:53,  9.00it/s]
# 548it [00:53,  9.06it/s]
# 549it [00:53,  8.68it/s]
# 550it [00:53,  8.67it/s]
# 552it [00:54,  9.45it/s]
# 553it [00:54,  9.27it/s]
# 555it [00:54, 10.20it/s]

# %%
#runner.model = tta.SegmentationTTAWrapper(model, transforms, merge_mode='mean')

# %%
runner.model
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (decoder): UnetDecoder(
#     (layer1): DecoderBlock(
#       (attention1): Identity()
#       (attention2): Identity()
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (layer2): DecoderBlock(
#       (attention1): Identity()
#       (attention2): Identity()
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (layer3): DecoderBlock(
#       (attention1): Identity()
#       (attention2): Identity()
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (layer4): DecoderBlock(
#       (attention1): Identity()
#       (attention2): Identity()
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (layer5): DecoderBlock(
#       (attention1): Identity()
#       (attention2): Identity()
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (final_conv): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
class_params = {}
for class_id in range(4):
    print(class_id)
    attempts = []
    for t in range(0, 100, 5):
        t /= 100
        for ms in [0, 100, 1200, 5000, 10000]:
            masks = []
            for i in range(class_id, len(probabilities), 4):
                probability = probabilities[i]
                predict, num_predict = post_process(sigmoid(probability), t, ms)
                masks.append(predict)

            d = []
            for i, j in zip(masks, valid_masks[class_id::4]):
                if (i.sum() == 0) & (j.sum() == 0):
                    d.append(1)
                else:
                    d.append(dice(i, j))

            attempts.append((t, ms, np.mean(d)))

    attempts_df = pd.DataFrame(attempts, columns=['threshold', 'size', 'dice'])


    attempts_df = attempts_df.sort_values('dice', ascending=False)
    print(attempts_df.head())
    best_threshold = attempts_df['threshold'].values[0]
    best_size = attempts_df['size'].values[0]
    
    class_params[class_id] = (best_threshold, best_size)
# Out:
# 0
#     threshold   size      dice
# 44       0.40  10000  0.602797
# 54       0.50  10000  0.602457
# 49       0.45  10000  0.601943
# 59       0.55  10000  0.601814
# 64       0.60  10000  0.600118
# 1
#     threshold   size      dice
# 8        0.05   5000  0.746638
# 9        0.05  10000  0.746566
# 14       0.10  10000  0.734273
# 7        0.05   1200  0.733927
# 13       0.10   5000  0.731966
# 2
#     threshold   size      dice
# 84       0.80  10000  0.591263
# 79       0.75  10000  0.586495
# 74       0.70  10000  0.584714
# 69       0.65  10000  0.583131
# 89       0.85  10000  0.578937
# 3
#     threshold   size      dice
# 29       0.25  10000  0.594847
# 24       0.20  10000  0.593200
# 23       0.20   5000  0.588063
# 34       0.30  10000  0.587537
# 19       0.15  10000  0.586438

# %%
    threshold   size      dice
74       0.70  10000  0.628590
64       0.60  10000  0.622684
69       0.65  10000  0.622125
79       0.75  10000  0.621332
59       0.55  10000  0.617064
1
    threshold   size      dice
54       0.50  10000  0.762203
24       0.20  10000  0.759306
59       0.55  10000  0.758294
49       0.45  10000  0.758154
64       0.60  10000  0.756959
2
    threshold   size      dice
64       0.60  10000  0.641841
59       0.55  10000  0.639953
69       0.65  10000  0.639231
74       0.70  10000  0.638155
54       0.50  10000  0.636323
3
    threshold   size      dice
44       0.40  10000  0.608100
49       0.45  10000  0.605580
39       0.35  10000  0.605266
59       0.55  10000  0.604301
64       0.60  10000  0.601393

# %% [markdown]
# 0
#     threshold   size      dice
# 84       0.80  10000  0.546952
# 79       0.75  10000  0.536471
# 89       0.85  10000  0.535483
# 74       0.70  10000  0.535009
# 69       0.65  10000  0.524628
# 1
#     threshold   size      dice
# 29       0.25  10000  0.702711
# 24       0.20  10000  0.698118
# 34       0.30  10000  0.697146
# 39       0.35  10000  0.694043
# 38       0.35   5000  0.693558
# 2

# %%
#class_params = {0: (0.7, 10000), 1: (0.5, 10000), 2: (0.6, 10000), 3: (0.4, 10000)}
print(class_params)
# Out:
# {0: (0.4, 10000), 1: (0.05, 5000), 2: (0.8, 10000), 3: (0.25, 10000)}

# %%
sns.lineplot(x='threshold', y='dice', hue='size', data=attempts_df);
plt.title('Threshold and min size vs dice for one of the classes');

# %%
for i, (input, output) in enumerate(zip(
        valid_dataset, runner.callbacks[0].predictions["logits"])):
    image, mask = input
        
    image_vis = image.transpose(1, 2, 0)
    mask = mask.astype('uint8').transpose(1, 2, 0)
    pr_mask = np.zeros((350, 525, 4))
    for j in range(4):
        probability = cv2.resize(output.transpose(1, 2, 0)[:, :, j], dsize=(525, 350), interpolation=cv2.INTER_LINEAR)
        pr_mask[:, :, j], _ = post_process(sigmoid(probability), class_params[j][0], class_params[j][1])
    #pr_mask = (sigmoid(output) > best_threshold).astype('uint8').transpose(1, 2, 0)
    
        
    visualize_with_raw(image=image_vis, mask=pr_mask, original_image=image_vis, original_mask=mask, raw_image=image_vis, raw_mask=output.transpose(1, 2, 0))
    
    if i >= 2:
        break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 98449

# %%
test_dataset = CloudDataset(df=sub, datatype='test', img_ids=test_ids, transforms = get_validation_augmentation(), preprocessing=get_preprocessing(preprocessing_fn))
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=8)

loaders = {"test": test_loader}

# %%
encoded_pixels = []
image_id = 0
for i, test_batch in enumerate(tqdm.tqdm(loaders['test'])):
    runner_out = runner.predict_batch({"features": test_batch[0].cuda()})['logits']
    for i, batch in enumerate(runner_out):
        for probability in batch:
            
            probability = probability.cpu().detach().numpy()
            if probability.shape != (350, 525):
                probability = cv2.resize(probability, dsize=(525, 350), interpolation=cv2.INTER_LINEAR)
            predict, num_predict = post_process(sigmoid(probability), class_params[image_id % 4][0], class_params[image_id % 4][1])
            if num_predict == 0:
                encoded_pixels.append('')
            else:
                r = mask2rle(predict)
                encoded_pixels.append(r)
            image_id += 1
# Out:
#   0%|          | 0/463 [00:00<?, ?it/s]
#   0%|          | 1/463 [00:03<28:44,  3.73s/it]
#   0%|          | 2/463 [00:04<22:37,  2.94s/it]
#   1%|          | 3/463 [00:05<16:57,  2.21s/it]
#   1%|          | 4/463 [00:05<12:36,  1.65s/it]
#   1%|          | 5/463 [00:06<09:40,  1.27s/it]
#   1%|▏         | 6/463 [00:06<08:13,  1.08s/it]
#   2%|▏         | 7/463 [00:07<06:41,  1.13it/s]
#   2%|▏         | 8/463 [00:07<05:38,  1.34it/s]
#   2%|▏         | 9/463 [00:07<04:52,  1.55it/s]
#   2%|▏         | 10/463 [00:08<03:55,  1.93it/s]
#   2%|▏         | 11/463 [00:08<03:36,  2.09it/s]
#   3%|▎         | 12/463 [00:09<03:42,  2.03it/s]
#   3%|▎         | 13/463 [00:09<03:18,  2.27it/s]
#   3%|▎         | 14/463 [00:09<03:23,  2.21it/s]
#   3%|▎         | 15/463 [00:10<03:17,  2.27it/s]
#   3%|▎         | 16/463 [00:10<03:09,  2.36it/s]
#   4%|▎         | 17/463 [00:11<03:03,  2.44it/s]
#   4%|▍         | 18/463 [00:11<02:43,  2.71it/s]
#   4%|▍         | 19/463 [00:11<03:00,  2.46it/s]
#   4%|▍         | 20/463 [00:12<02:54,  2.54it/s]
#   5%|▍         | 21/463 [00:12<03:02,  2.42it/s]
#   5%|▍         | 22/463 [00:13<03:06,  2.36it/s]
#   5%|▍         | 23/463 [00:13<03:05,  2.38it/s]
#   5%|▌         | 24/463 [00:13<03:07,  2.34it/s]
#   5%|▌         | 25/463 [00:14<02:55,  2.49it/s]
#   6%|▌         | 26/463 [00:14<02:50,  2.57it/s]
#   6%|▌         | 27/463 [00:15<02:48,  2.59it/s]
#   6%|▌         | 28/463 [00:15<03:01,  2.40it/s]
#   6%|▋         | 29/463 [00:15<03:01,  2.40it/s]
#   6%|▋         | 30/463 [00:16<03:06,  2.32it/s]
#   7%|▋         | 31/463 [00:16<02:58,  2.42it/s]
#   7%|▋         | 32/463 [00:17<02:59,  2.40it/s]
#   7%|▋         | 33/463 [00:17<03:05,  2.32it/s]
#   7%|▋         | 34/463 [00:18<02:55,  2.44it/s]
#   8%|▊         | 35/463 [00:18<02:50,  2.51it/s]
#   8%|▊         | 36/463 [00:18<02:49,  2.53it/s]
#   8%|▊         | 37/463 [00:19<02:41,  2.63it/s]
#   8%|▊         | 38/463 [00:19<02:57,  2.40it/s]
#   8%|▊         | 39/463 [00:20<02:53,  2.44it/s]
#   9%|▊         | 40/463 [00:20<02:44,  2.58it/s]
#   9%|▉         | 41/463 [00:20<02:40,  2.62it/s]
#  98%|█████████▊| 455/463 [03:03<00:01,  5.42it/s]
#  98%|█████████▊| 456/463 [03:03<00:01,  5.85it/s]
#  99%|█████████▊| 457/463 [03:03<00:00,  6.17it/s]
#  99%|█████████▉| 458/463 [03:04<00:00,  6.41it/s]
#  99%|█████████▉| 459/463 [03:04<00:00,  6.56it/s]
#  99%|█████████▉| 460/463 [03:04<00:00,  6.40it/s]
# 100%|█████████▉| 461/463 [03:04<00:00,  6.38it/s]
# 100%|██████████| 463/463 [03:05<00:00,  2.50it/s]

# %%
sub['EncodedPixels'] = encoded_pixels
sub.to_csv('submission_v10_ntta_newaugs_baseline.csv', columns=['Image_Label', 'EncodedPixels'], index=False)

# %%
a = pd.read_csv('submission_v8_tta_newaugs_baseline.csv')
b = pd.read_csv('submission_v8_ntta_newaugs_baseline.csv')

# %%
a.head(10)
# Out:
#           Image_Label                                      EncodedPixels
# 0    002f507.jpg_Fish                                                NaN
# 1  002f507.jpg_Flower                                                NaN
# 2  002f507.jpg_Gravel  9 309 353 344 702 347 1052 347 1401 348 1751 3...
# 3   002f507.jpg_Sugar                                                NaN
# 4    0035ae9.jpg_Fish                                                NaN
# 5  0035ae9.jpg_Flower                                                NaN
# 6  0035ae9.jpg_Gravel  792 29 828 59 1137 119 1485 122 1833 124 2182 ...
# 7   0035ae9.jpg_Sugar  261 20 298 39 600 99 943 107 1292 108 1641 110...
# 8    0038327.jpg_Fish                                                NaN
# 9  0038327.jpg_Flower                                                NaN

# %%
b.head(100)
# Out:
#            Image_Label                                      EncodedPixels
# 0     002f507.jpg_Fish                                                NaN
# 1   002f507.jpg_Flower                                                NaN
# 2   002f507.jpg_Gravel  5 330 353 344 702 347 1051 348 1401 349 1751 3...
# 3    002f507.jpg_Sugar                                                NaN
# 4     0035ae9.jpg_Fish                                                NaN
# ..                 ...                                                ...
# 95   0167118.jpg_Sugar                                                NaN
# 96    016eec3.jpg_Fish                                                NaN
# 97  016eec3.jpg_Flower                                                NaN
# 98  016eec3.jpg_Gravel                                                NaN
# 99   016eec3.jpg_Sugar  62218 10 62564 21 62911 28 63259 33 63606 38 6...
#
# [100 rows x 2 columns]

# %%
sub.head(10)
# Out:
#           Image_Label                                      EncodedPixels  \
# 0    002f507.jpg_Fish
# 1  002f507.jpg_Flower
# 2  002f507.jpg_Gravel  8 328 353 345 702 347 1052 347 1402 348 1752 3...
# 3   002f507.jpg_Sugar
# 4    0035ae9.jpg_Fish
# 5  0035ae9.jpg_Flower
# 6  0035ae9.jpg_Gravel  448 107 782 133 1129 141 1478 142 1827 143 217...
# 7   0035ae9.jpg_Sugar  242 101 593 106 938 112 1287 113 1637 113 1987...
# 8    0038327.jpg_Fish
# 9  0038327.jpg_Flower
#
#     label        im_id
# 0    Fish  002f507.jpg
# 1  Flower  002f507.jpg
# 2  Gravel  002f507.jpg
# 3   Sugar  002f507.jpg
# 4    Fish  0035ae9.jpg
# 5  Flower  0035ae9.jpg
# 6  Gravel  0035ae9.jpg
# 7   Sugar  0035ae9.jpg
# 8    Fish  0038327.jpg
# 9  Flower  0038327.jpg

# %%
x = pd.read_csv('submission_v4_newaugs_baseline.csv')

# %%
x.head(10)
# Out:
#           Image_Label                                      EncodedPixels
# 0    002f507.jpg_Fish                                                NaN
# 1  002f507.jpg_Flower                                                NaN
# 2  002f507.jpg_Gravel  9 314 353 345 702 347 1051 349 1401 349 1751 3...
# 3   002f507.jpg_Sugar                                                NaN
# 4    0035ae9.jpg_Fish                                                NaN
# 5  0035ae9.jpg_Flower                                                NaN
# 6  0035ae9.jpg_Gravel  422 233 761 280 1103 294 1449 299 1797 302 214...
# 7   0035ae9.jpg_Sugar  4474 2 4542 3 4823 4 4891 6 4898 1 5154 4 5173...
# 8    0038327.jpg_Fish                                                NaN
# 9  0038327.jpg_Flower                                                NaN

# %%
y = x.merge(sub,on='Image_Label',how='left')

# %%
y.head(10)
# Out:
#           Image_Label                                    EncodedPixels_x  \
# 0    002f507.jpg_Fish                                                NaN
# 1  002f507.jpg_Flower                                                NaN
# 2  002f507.jpg_Gravel  9 314 353 345 702 347 1051 349 1401 349 1751 3...
# 3   002f507.jpg_Sugar                                                NaN
# 4    0035ae9.jpg_Fish                                                NaN
# 5  0035ae9.jpg_Flower                                                NaN
# 6  0035ae9.jpg_Gravel  422 233 761 280 1103 294 1449 299 1797 302 214...
# 7   0035ae9.jpg_Sugar  4474 2 4542 3 4823 4 4891 6 4898 1 5154 4 5173...
# 8    0038327.jpg_Fish                                                NaN
# 9  0038327.jpg_Flower                                                NaN
#
#                                      EncodedPixels_y   label        im_id
# 0                                                       Fish  002f507.jpg
# 1                                                     Flower  002f507.jpg
# 2  8 328 353 345 702 347 1052 347 1402 348 1752 3...  Gravel  002f507.jpg
# 3                                                      Sugar  002f507.jpg
# 4                                                       Fish  0035ae9.jpg
# 5                                                     Flower  0035ae9.jpg
# 6  448 107 782 133 1129 141 1478 142 1827 143 217...  Gravel  0035ae9.jpg
# 7  242 101 593 106 938 112 1287 113 1637 113 1987...   Sugar  0035ae9.jpg
# 8                                                       Fish  0038327.jpg
# 9                                                     Flower  0038327.jpg

# %%
type(y[y['Image_Label'] == '002f507.jpg_Gravel']['EncodedPixels_y'])
# Out:
# pandas.core.series.Series

# %%
y['EncodedPixels'] = (len(y['EncodedPixels_x']),len(y['EncodedPixels_y']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-85b59dcd4e3b> in <module>
# ----> 1 y['EncodedPixels'] = (len(y['EncodedPixels_x']),len(y['EncodedPixels_y']))
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
